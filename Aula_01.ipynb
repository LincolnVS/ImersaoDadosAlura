# %% [markdown]
# <a href="https://colab.research.google.com/github/LincolnVS/ImersaoDadosAlura/blob/main/Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula

# %% [markdown]
# ##Olá!

# %% [markdown]
# Seja bem-vinda ou bem-vindo ao notebook da aula 01, nesta aula vamos realizar nossa primeira análise de dados e no final já seremos capazes de tirar algumas conclusões.
#
# Nós desenvolveremos nosso projeto aqui no google colaboratory, assim podemos mesclar células contendo textos em formato markdown e células de código, além disso você não precisa instalar nada na sua máquina. Então, que tal começar testando algumas linhas de código?
#
# No campo abaixo temos o que chamamos de célula. Na célula nós podemos digitar textos, cálculos e códigos.
#
# Após eu introduzir o que eu quero na célula eu vou rodar esse conteúdo. Para isso podemos usar o atalho SHIFT + ENTER, ou até mesmo clicar no símbolo de play no canto esquerdo da célula. Na primeira vez que rodamos algo no nosso notebook ele vai demorar um pouco mais de tempo, e isso ocorre porque o google está alocando uma máquina virtual para nós utilizarmos.
#
# Vamos então fazer alguns testes, como os exemplos abaixo:

# %%
10 + 10
# Out:
# 20

# %%
'Thiago'
# Out:
# 'Thiago'

# %% [markdown]
# ## Importando os dados
#
# Nessa imersão nós vamos mergulhar no universo da biologia e da biotecnologia e explorar uma base de dados da área.
#
# Para a nossa análise, está faltando então os dados. Para conseguirmos esses dados vamos acessar o Github, nesse link:
#
# https://github.com/alura-cursos/imersaodados3/tree/main/dados
#
# Então, agora vamos importar essa base de dados para dentro do nosso notebook. Para juntar essas informações vamos utilizar nossa famosa biblioteca do "Pandas".
# Vamos importar essa biblioteca através do seguinte código:

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# Observe que imprimimos agora todas as nossas linhas e colunas da nossa tabela.
#
# Aqui observamos que temos dados referentes a ID, tratamento, tempo, dose, entre outras.
#
# Para nos auxiliar na visualização e na identificação das colunas dos dados que vamos trabalhar, faremos um recorte, uma espécie de cabeçalho, com 5 linhas, e para isso usamos o seguinte comando:

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# Quando estávamos trabalhando com o conjunto total de dados nós tínhamos a informação do número total de linhas e colunas. Porém, agora com o head, nós perdemos essa informação. Então, caso você queira recuperar a informação do total de linhas e colunas basta utilizar:

# %%
dados.shape
# Out:
# (23814, 877)

# %% [markdown]
# Então, agora vamos voltar para o nosso problema.
#
# Nós queremos iniciar fazendo uma análise dos dados que estamos tratando. Vamos começar selecionando só uma coluna, para entendermos do que ela está tratando.
#
# Vamos iniciar com a coluna tratamento. Para isso vamos digitar:

# %%
dados['tratamento']
# Out:
# 0           com_droga
# 1           com_droga
# 2           com_droga
# 3           com_droga
# 4           com_droga
#              ...
# 23809       com_droga
# 23810       com_droga
# 23811    com_controle
# 23812       com_droga
# 23813       com_droga
# Name: tratamento, Length: 23814, dtype: object

# %% [markdown]
# Esse tipo de informação, da coluna, é o que chamamos de 'série'. Já a tabela inteira nós chamos de 'dataframe'.
#
# Agora para vermos os tipos específicos de informação que temos dentro dessa coluna vamos digitar:

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# A resposta foi dada no formato de array, que nada mais é do que um vetor, ou seja, um tipo de estrutura de dados.
#
# Observe que encontramos dois tipos: 'com droga' e 'com controle'.
#
# Com droga, como o próprio nome nos diz, é quando estamos aplicando algum tipo de droga para a amostra. Já com o controle é uma técnica estatística em que isolamos as outras varíaveis e observamos apenas a variável de interesse.

# %% [markdown]
# Agora vamos analisar a coluna do tempo:

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# Encontramos 3 tipos de informação nessa coluna: 24, 72 e 48. O que pode nos indicar o tempo, provavelmente em horas, de intervalo que foi administrada a dose de medicamentos ou drogas.
#
# É interessante que observamos o comportamento das células com essa diferença de tempo, já que se analisássemos num período diferente poderia não dar tempo suficiente pra célula manifestar o determinado comportamento.

# %% [markdown]
# Além do tempo, podemos analisar também a coluna de dose:

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %% [markdown]
# Aqui obtemos dois tipos de doses diferentes, d1 e d2, mas não conseguimos afirmar nada categoricamente de antemão.

# %% [markdown]
# Vamos então analisar a categoria droga:

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# Agora com a resposta de ```dados['droga'].unique()``` obtivemos essa série de códigos como resposta. Talvez esses números foram codificados na tentativa de anonimizar os tipos de drogas usadas, para tentar evitar qualquer tipo de viés na análise dos resultados.
#
# Há uma série de regras quando alguns experimentos são feitos, evitando mostrar dados como nome, sexo, e outros fatores, dependendo da análise a ser feita, para que sejam evitados vieses.

# %% [markdown]
# Vamos analisar a coluna nomeada como g-0 agora:

# %%
dados['g-0'].unique()
# Out:
# array([ 1.062 ,  0.0743,  0.628 , ...,  0.3942,  0.666 , -0.8598])

# %% [markdown]
# Só olhando fica difícil tentar deduzir o que esses números representam. Então, nesse ponto, com o auxílio da Vanessa, especialista, conseguimos a informação que essa letra 'g' da coluna remete à palavra gene. Ou seja, esses números nos dizem a expressão de cada gene frente as drogas ou a exposição.
#
# Quando subimos de volta na tabela, percebemos que há diversos valores, inclusive com várias casas decimais. Aparentemente esses números foram "arredondados", normalizados, para podermos compará-los de alguma forma.
#
# Então, até agora na nossa análise, já conseguimos identificar e entender as informações de diferentes colunas; as colunas que nos indicam os tratamentos, as drogas, o tempo, e depois as respostas genéticas, que tem a letra g no ínicio do seu nome.
#
# Outro tipo de análise que podemos fazer agora é entender a distribuição dessas informações. Por exemplo, podemos saber quantos experimentos temos utilizando droga e quantos não utilizam; quantos usam o d1, e quantos utilizam o d2, e assim por diante.
#
# Como podemos fazer isso? Vamos utilizar esse código:

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Agora, em vez de usarmos o ```.unique``` no código, nós utilizamos o ```.value_counts``` já que nosso objetivo era contar a quantidade de valores que apareciam nas colunas, nesse caso, na coluna ```tratamento```.
#
# No resultado ele retornou 2 linhas: uma com a quantidade de elementos que temos, ou seja, com a minha frequência, na categoria ```com_droga``` e a outra com a quantidade que temos na categoria ```com_controle```.
#
# Houve uma grande diferença no resultado dessas categorias, não é mesmo? Isso é, no mínimo, curioso. Então, Guilherme vai nos sugerir um desafio, de investigar o por quê dessa diferença tão grande.
#
# Nesse momento o Thiago já escreve outros dois desafios, o desafio #2 e o desafio #3. E a Vanessa também deixa o seu, desafio #4. Todos os desafios dessa aula estão escritos no final desse notebook.

# %% [markdown]
# Será que essa diferença entre os valores dentro das categorias continuam tão desproporcionais? Vamos investigar a categoria ```dose```:

# %%
dados['dose'].value_counts()
# Out:
# D1    12147
# D2    11667
# Name: dose, dtype: int64

# %% [markdown]
# Nesse ponto parece que as coisas já estão mais equilibradas. Mas somente com o número é difícil fazermos uma leitura mais aprofundada. Então, nesse momento, vamos resolver um dos desafios deixados. Então, se até aqui você ainda nao resolveu os desafios do vídeo e nao quer receber um spoiler, pare aqui e tente resolvê-los primeiro.

# %% [markdown]
# Para entendermos melhor e fazer um comparativo é legal traçarmos a proporção entre os dados. Vamos escrever o código agora, setando como parâmetro, dentro dos parênteses o ```normalize = True``` :

# %%
dados['tratamento'].value_counts(normalize = True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %% [markdown]
# Temos agora os dados "normalizados". Podemos interpretar utilizando a porcentagem (multiplicando por 100), o que nos daria algo em torno de 92% versus 8% (aproximadamente), mostrando o tamanho da desproporção.

# %% [markdown]
# Vamos fazer o mesmo agora com a coluna ```dose```:

# %%
dados['dose'].value_counts(normalize = True)
# Out:
# D1    0.510078
# D2    0.489922
# Name: dose, dtype: float64

# %% [markdown]
# Temos aqui o resultado. Inclusive, como mini-desafio, você pode fazer o mesmo processo com as outras colunas.
#
# Certo, mas geralmente, quando há a trasmissão dessas informações, vemos uma série de gráficos. E, geralmente, é usado aquele gráfico que parece uma torta, ou uma pizza.
#
# Vamos então plotar um gráfico dessa tipo, com o seguinte código:

# %%
dados['tratamento'].value_counts().plot.pie()

# %% [markdown]
# Aqui, em azul, nós temos a quantidade de tratamento com drogas(que é muito maior, em proporção), e em laranja temos o tratamento "com controle". Ficou até parecendo um pacman, hehe.
#
# Vamos aproveitar e analisar as outras informações com os gráficos também, para vermos o que acontece. Vamos analisar a coluna tempo:

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# Repare como ficou difícil a olho nú identificarmos qual observação é maior através do gráfico. Esse tipo de gráfico pode acabar dificultando um pouco a análise, especialmente quando as informações estão melhor balanceadas.
#
# Além de identificar a quantidade de horas observadas, nós não conseguimos extrair mais nenhuma informação desse gráfico. Inclusive, nós temos uma espécie de regrinha, que diz que quando formos fazer algum tipo de análise, procurarmos evitar o uso de gráficos que nos remetem a comida, como por exemplo: rosca, pizza, torta, e assim por diante.
#
# Então qual tipo de gráfico poderíamos utlizar para melhorarmos nossa visualização? Vamos utilizar o gráfico de barras, através deste código:

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# Agora sim conseguimos identificar com mais facilidade qual observação tem a sua maior frequência. Na verdade a quantidade de horas com o maior número de observações foi a de 48.
#
# No eixo y temos o número que nos remete ao número de observações. Então podemos observar que tivemos pouco mais de 8000 observações relativas às 48 horas.
#
# Então, o gráfico de barras acabou sendo muit mais útil, nesse caso, do que o gráfico de pizza.

# %% [markdown]
# Ao longo da aula nós falamos sobre a expressão gênica. Se nós voltarmos à tabela, na coluna g-0, nós temos alguns valores dentro de um intervalo definido. Para não termos valores muito distantes entre si, é bastante comum no meio científico que haja uma normalização dos resultados, para criamos um intervalo que não seja tão grande, em que o meio dessa distribuição seja o 0.
#
# Como nós podemos saber em quais linhas dessa coluna, o meu valor está acima de 0?
#
# Vamos fazer uma consulta nos nossos dados, da seguinte maneira:

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# Dessa maneira, temos somente as 5 primeiras linhas com o valores maiores do que 0 na coluna g-0, com a ajuda dessa máscara com o código ```[dados['g-0']>0]```.
#
# Dessa mesma forma que aplicamos essa máscara, podemos utilizar o mesmo caminho, ou outras 'querys', para responder várias outras perguntas.
#
# Assim, temos outro desafio, o #5, de procurar na documentação do pandas o método query.
#
# Além desse temos outros desafios, o #6 e o #7 e o #8, todos eles estão logo abaixo.

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [23814 rows x 877 columns]

# %% [markdown]
# # Playground (testes e afins)

# %% [markdown]
# ### Importando dados

# %%
import pandas as pd
import matplotlib.pyplot as plt

url_dados = 'https://github.com/LincolnVS/ImersaoDadosAlura/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')

# %% [markdown]
# ### Entender os dados

# %%
colunas_apresentadas = ['id','tratamento','tempo','dose','droga','g-0','g-1','g-2','g-3']
dados[colunas_apresentadas].head(5)
# Out:
#              id tratamento  tempo dose  ...     g-0     g-1     g-2     g-3
# 0  id_000644bb2  com_droga     24   D1  ...  1.0620  0.5577 -0.2479 -0.6208
# 1  id_000779bfc  com_droga     72   D1  ...  0.0743  0.4087  0.2991  0.0604
# 2  id_000a6266a  com_droga     48   D1  ...  0.6280  0.5817  1.5540 -0.0764
# 3  id_0015fd391  com_droga     48   D1  ... -0.5138 -0.2491 -0.2656  0.5288
# 4  id_001626bd3  com_droga     72   D2  ... -0.3254 -0.4009  0.9700  0.6919
#
# [5 rows x 9 columns]

# %% [markdown]
# Entendendo os dados
#
# - id = identificador único para cada experimento {0 até 23813}
#
# - tempo = tempo de espera para entender {24, 48, 72}
#
# - tratamento = categorias {com_droga, com_controle}
#
# - dose = Diferentes Dosagens {D1, D2}
#
# - drogas = tipos de substâncias testadas {Drogas com nomes anonimos para não ter viés}
#
# - g_x = dados de expressão genética, dados normalizados {provavelmente de -2 a 2}

# %%
#avaliando o formato do dataset
linha, coluna = dados.shape
print(f'A base de dados possui {linha} experimentos e {coluna} variáveis.')
# Out:
# A base de dados possui 23814 experimentos e 877 variáveis.

# %%
dict_tempos = dados['tempo'].value_counts().to_dict()

for key in dict_tempos:
  print(f"Temos {dict_tempos[key]} amostras com {key} horas")
# Out:
# Temos 8250 amostras com 48 horas
# Temos 7792 amostras com 72 horas
# Temos 7772 amostras com 24 horas

# %%
dict_drogas = dados['droga'].value_counts().to_dict()

for key in dict_drogas:
  print(f"Temos {dict_drogas[key]} amostras com a droga {key}")
# Out:
# Temos 1866 amostras com a droga cacb2b860
# Temos 718 amostras com a droga 87d714366
# Temos 246 amostras com a droga 9f80f3f77
# Temos 203 amostras com a droga 8b87a7a83
# Temos 202 amostras com a droga 5628cb3ee
# Temos 196 amostras com a droga d08af5d4b
# Temos 194 amostras com a droga 292ab2c28
# Temos 186 amostras com a droga d50f18348
# Temos 178 amostras com a droga d1b47f29d
# Temos 19 amostras com a droga 67c879e79
# Temos 18 amostras com a droga 52d1e6f43
# Temos 18 amostras com a droga d488d031d
# Temos 18 amostras com a droga 83a9ea167
# Temos 14 amostras com a droga 1a52478dc
# Temos 14 amostras com a droga a7c2673c1
# Temos 14 amostras com a droga 30aa2f709
# Temos 14 amostras com a droga 6b8b675cc
# Temos 14 amostras com a droga 5d9bb0ebe
# Temos 14 amostras com a droga 11f66c124
# Temos 13 amostras com a droga 1d3112471
# Temos 13 amostras com a droga d149a15f5
# Temos 13 amostras com a droga aa7b9f4cc
# Temos 13 amostras com a droga 10dbb5b2a
# Temos 13 amostras com a droga 0b1ed98a0
# Temos 13 amostras com a droga f92989f8d
# Temos 13 amostras com a droga 3ff075492
# Temos 13 amostras com a droga ab50adc64
# Temos 13 amostras com a droga 02ae89796
# Temos 13 amostras com a droga b3031b373
# Temos 13 amostras com a droga bb3b7c7d5
# Temos 13 amostras com a droga 8c91d6909
# Temos 13 amostras com a droga d3ff26fc7
# Temos 13 amostras com a droga e0cd5c091
# Temos 13 amostras com a droga 1d4c91026
# Temos 13 amostras com a droga af12e2904
# Temos 13 amostras com a droga 61155e673
# Temos 13 amostras com a droga 20a3c3f90
# Temos 13 amostras com a droga 5a518a0f0
# Temos 13 amostras com a droga 1d6d22a71
# Temos 13 amostras com a droga 88c37c66a
# Temos 13 amostras com a droga fd4387eac
# Temos 13 amostras com a droga 03b09563c
# Temos 13 amostras com a droga 2f5b9b3bd
# Temos 13 amostras com a droga a44e72ca3
# Temos 12 amostras com a droga bda439de9
# Temos 12 amostras com a droga 93303298e
# Temos 12 amostras com a droga 24a3fbf37
# Temos 12 amostras com a droga 1b09b35f0
# Temos 12 amostras com a droga afd0dbace
# Temos 12 amostras com a droga 6b2d73b7d
# Temos 12 amostras com a droga 0249e20c4
# Temos 12 amostras com a droga 472eaa5fd
# Temos 12 amostras com a droga e78c48114
# Temos 12 amostras com a droga 20c9d8e5c
# Temos 12 amostras com a droga 46befd494
# Temos 12 amostras com a droga 754486b37
# Temos 12 amostras com a droga 68869f4e9
# Temos 12 amostras com a droga 34cb34a74
# Temos 12 amostras com a droga 7473b8828
# Temos 12 amostras com a droga 55e4096d8
# Temos 12 amostras com a droga 50e38451f
# Temos 12 amostras com a droga 2688e0167
# Temos 12 amostras com a droga 0994324f7
# Temos 12 amostras com a droga ef8b7fe07
# Temos 12 amostras com a droga 24c787f29
# Temos 12 amostras com a droga 00321ea80
# Temos 12 amostras com a droga 3610da8fc
# Temos 12 amostras com a droga e66896455
# Temos 12 amostras com a droga e23fb6c1c
# Temos 12 amostras com a droga 1df2f9781
# Temos 12 amostras com a droga 1344cf491
# Temos 12 amostras com a droga 6def270ae
# Temos 12 amostras com a droga 4a65421e6
# Temos 12 amostras com a droga 404e713a8
# Temos 12 amostras com a droga de7b27dbc
# Temos 12 amostras com a droga b30c11496
# Temos 12 amostras com a droga 82da03539
# Temos 12 amostras com a droga 3a383db4a
# Temos 12 amostras com a droga 96c2fddf7
# Temos 12 amostras com a droga 39cc616d2
# Temos 12 amostras com a droga a3066427d
# Temos 12 amostras com a droga 357bf33db
# Temos 12 amostras com a droga d73b6a4a2
# Temos 12 amostras com a droga 5aa46f542
# Temos 12 amostras com a droga 043fedc3f
# Temos 12 amostras com a droga 8bfccb68b
# Temos 12 amostras com a droga e651aad68
# Temos 12 amostras com a droga c3273cd04
# Temos 12 amostras com a droga ae0c59f9b
# Temos 12 amostras com a droga f2cd513d6
# Temos 12 amostras com a droga 91b11acc4
# Temos 12 amostras com a droga 824a6c1ca
# Temos 12 amostras com a droga d632db159
# Temos 12 amostras com a droga 4ddf83a79
# Temos 12 amostras com a droga 8ed81dd51
# Temos 12 amostras com a droga f4f4771c9
# Temos 12 amostras com a droga 9e25474f1
# Temos 12 amostras com a droga 5c68cde71
# Temos 12 amostras com a droga e57f7453e
# Temos 12 amostras com a droga 95a5b4f7e
# Temos 12 amostras com a droga 5fe9c41db
# Temos 12 amostras com a droga b6dc8d1e1
# Temos 12 amostras com a droga 1b20d8d8d
# Temos 12 amostras com a droga 8c7f86626
# Temos 12 amostras com a droga e572e62e2
# Temos 12 amostras com a droga 3df6fc891
# Temos 12 amostras com a droga 9aff06a16
# Temos 12 amostras com a droga fe8625cad
# Temos 11 amostras com a droga a2a054566
# Temos 11 amostras com a droga 42446ee76
# Temos 11 amostras com a droga d74175a91
# Temos 11 amostras com a droga 8a4370a9b
# Temos 8 amostras com a droga 7db360ff6
# Temos 8 amostras com a droga e53bd9396
# Temos 8 amostras com a droga 26574c800
# Temos 8 amostras com a droga 18c37e601
# Temos 7 amostras com a droga adfbd607a
# Temos 7 amostras com a droga 0a5a4f458
# Temos 7 amostras com a droga 6895c50ed
# Temos 7 amostras com a droga d38a2d3ef
# Temos 7 amostras com a droga dd313d89e
# Temos 7 amostras com a droga 57ccb23c1
# Temos 7 amostras com a droga 0cc68ee7c
# Temos 7 amostras com a droga a1f4f1154
# Temos 7 amostras com a droga 5b132e580
# Temos 7 amostras com a droga d01936d7e
# Temos 7 amostras com a droga 7f69271a1
# Temos 7 amostras com a droga 4b138d0a8
# Temos 7 amostras com a droga 2d3cb8f30
# Temos 7 amostras com a droga c63a7ee15
# Temos 7 amostras com a droga eb1abad45
# Temos 7 amostras com a droga 2f2e37eda
# Temos 7 amostras com a droga db657e8ac
# Temos 7 amostras com a droga c46beda84
# Temos 7 amostras com a droga 98d258152
# Temos 7 amostras com a droga 3b1b7319a
# Temos 7 amostras com a droga ca8854531
# Temos 7 amostras com a droga e5922d23c
# Temos 7 amostras com a droga 26f1351c1
# Temos 7 amostras com a droga 23b0c6122
# Temos 7 amostras com a droga 1c3236de2
# Temos 7 amostras com a droga 67b8f0a99
# Temos 7 amostras com a droga 8229f1030
# Temos 7 amostras com a droga 649d95014
# Temos 7 amostras com a droga 0f2ec8169
# Temos 7 amostras com a droga f228f319c
# Temos 7 amostras com a droga b2bce570f
# Temos 7 amostras com a droga 6324b63b6
# Temos 7 amostras com a droga 31cdc0d4a
# Temos 7 amostras com a droga bbec32b06
# Temos 7 amostras com a droga e20a1c258
# Temos 7 amostras com a droga 9898cba0d
# Temos 7 amostras com a droga c4fd19474
# Temos 7 amostras com a droga 5735a3e0f
# Temos 7 amostras com a droga b16c06e60
# Temos 7 amostras com a droga ea8db5dd6
# Temos 7 amostras com a droga abe5d0dcc
# Temos 7 amostras com a droga 6dfda028e
# Temos 7 amostras com a droga c7ecff8b4
# Temos 7 amostras com a droga 65d7f344a
# Temos 7 amostras com a droga 3fcf6c45a
# Temos 7 amostras com a droga af22cc3d8
# Temos 7 amostras com a droga ad84986d3
# Temos 7 amostras com a droga 29ea347ea
# Temos 7 amostras com a droga 0957d670d
# Temos 7 amostras com a droga a2f3f1f63
# Temos 7 amostras com a droga bb9ea924c
# Temos 7 amostras com a droga ee806f8a1
# Temos 7 amostras com a droga b439cd83a
# Temos 7 amostras com a droga 5387c8eaa
# Temos 7 amostras com a droga 56e484932
# Temos 7 amostras com a droga 825e3a43c
# Temos 7 amostras com a droga 989a4f93d
# Temos 7 amostras com a droga a13f301e0
# Temos 7 amostras com a droga 991dccfc4
# Temos 7 amostras com a droga b1795fcb0
# Temos 7 amostras com a droga ff551f3a3
# Temos 7 amostras com a droga 925488749
# Temos 7 amostras com a droga 260a804ec
# Temos 7 amostras com a droga 12fd34362
# Temos 7 amostras com a droga 2abc6c21e
# Temos 7 amostras com a droga 94ce06893
# Temos 7 amostras com a droga 2266410ca
# Temos 7 amostras com a droga 2f1db8c6c
# Temos 7 amostras com a droga 3ed7ea58f
# Temos 7 amostras com a droga cedb6c4a8
# Temos 7 amostras com a droga 28bdee607
# Temos 7 amostras com a droga be3cd78c2
# Temos 7 amostras com a droga 285fbb0b0
# Temos 7 amostras com a droga 721fbbc54
# Temos 7 amostras com a droga 3e677daea
# Temos 7 amostras com a droga f007bd74e
# Temos 7 amostras com a droga 0393401cc
# Temos 7 amostras com a droga 7ab43c75d
# Temos 7 amostras com a droga efd859187
# Temos 7 amostras com a droga 3f2f378cf
# Temos 7 amostras com a droga 24ac0214f
# Temos 7 amostras com a droga 035a6a762
# Temos 7 amostras com a droga cbc278c8c
# Temos 7 amostras com a droga 3710f60fa
# Temos 7 amostras com a droga 87705adb2
# Temos 7 amostras com a droga 14b9e5384
# Temos 7 amostras com a droga df9c4c6af
# Temos 7 amostras com a droga ab5979bc0
# Temos 7 amostras com a droga 8ab72a1bc
# Temos 7 amostras com a droga 4b3c59823
# Temos 7 amostras com a droga c6e681fa2
# Temos 7 amostras com a droga 3628040f9
# Temos 7 amostras com a droga 6511c8e6e
# Temos 7 amostras com a droga 3cda750b5
# Temos 7 amostras com a droga f2b81ca2e
# Temos 7 amostras com a droga 9d1c9eb50
# Temos 7 amostras com a droga bd9cf521f
# Temos 7 amostras com a droga 399cbeb3e
# Temos 7 amostras com a droga 8e62620d4
# Temos 7 amostras com a droga dd4b64a59
# Temos 7 amostras com a droga fbd77dbb9
# Temos 7 amostras com a droga 6a1616f45
# Temos 7 amostras com a droga 03b81e62e
# Temos 7 amostras com a droga 908482858
# Temos 7 amostras com a droga d9f666bcd
# Temos 7 amostras com a droga 9900aeef2
# Temos 7 amostras com a droga f48d611be
# Temos 7 amostras com a droga 123bd9005
# Temos 7 amostras com a droga b96fb04fa
# Temos 7 amostras com a droga 872bc007e
# Temos 7 amostras com a droga 6274c8c1f
# Temos 7 amostras com a droga b266bfb86
# Temos 7 amostras com a droga eacb563b3
# Temos 7 amostras com a droga 6ef24fb20
# Temos 7 amostras com a droga 146ba19d5
# Temos 7 amostras com a droga 244ef8123
# Temos 7 amostras com a droga 5ec98e006
# Temos 7 amostras com a droga fc4cd4585
# Temos 7 amostras com a droga e160a2b00
# Temos 7 amostras com a droga d6cf25434
# Temos 7 amostras com a droga ea8ed8051
# Temos 7 amostras com a droga 8693b40e8
# Temos 7 amostras com a droga c106a3f18
# Temos 7 amostras com a droga 8b03bfee8
# Temos 7 amostras com a droga 7d1d72083
# Temos 7 amostras com a droga 508e74297
# Temos 7 amostras com a droga 9288cf822
# Temos 7 amostras com a droga d631fcc6c
# Temos 7 amostras com a droga 3f8e9f8cf
# Temos 7 amostras com a droga 3daf3ab5b
# Temos 7 amostras com a droga 481a0c086
# Temos 7 amostras com a droga 853dca78a
# Temos 7 amostras com a droga 538ff01f5
# Temos 7 amostras com a droga 6a7fd5fd2
# Temos 7 amostras com a droga 0dcd1acb9
# Temos 7 amostras com a droga 3a02fdb9b
# Temos 7 amostras com a droga 18bb41b2c
# Temos 7 amostras com a droga 9cbacb6de
# Temos 7 amostras com a droga 3859c44f3
# Temos 7 amostras com a droga f9d0d8f63
# Temos 7 amostras com a droga 8abbf7b55
# Temos 7 amostras com a droga 31d5cf076
# Temos 7 amostras com a droga e66734551
# Temos 7 amostras com a droga 47bcdff9d
# Temos 7 amostras com a droga e610a38d4
# Temos 7 amostras com a droga bd30d81ce
# Temos 7 amostras com a droga 847fbc822
# Temos 7 amostras com a droga 70cd13738
# Temos 7 amostras com a droga 701fd55ef
# Temos 7 amostras com a droga 57f7c6a5c
# Temos 7 amostras com a droga 9ef936a40
# Temos 7 amostras com a droga bcaae6660
# Temos 7 amostras com a droga 6f430a5f0
# Temos 7 amostras com a droga 3c195fc5b
# Temos 7 amostras com a droga bc8f3b60e
# Temos 7 amostras com a droga eef00a2d4
# Temos 7 amostras com a droga 816767bf6
# Temos 7 amostras com a droga 519d5133b
# Temos 7 amostras com a droga 1b1a45a6b
# Temos 7 amostras com a droga 6540c0b79
# Temos 7 amostras com a droga 1196f6507
# Temos 7 amostras com a droga 9b964b696
# Temos 7 amostras com a droga c89f8f935
# Temos 7 amostras com a droga 07bd8c42c
# Temos 7 amostras com a droga 014d175d7
# Temos 7 amostras com a droga feb9315c0
# Temos 7 amostras com a droga d032e3d51
# Temos 7 amostras com a droga 728eb0f63
# Temos 7 amostras com a droga 702238187
# Temos 7 amostras com a droga 3c8c824ff
# Temos 7 amostras com a droga 5ac378d8a
# Temos 7 amostras com a droga 5e6359c7c
# Temos 7 amostras com a droga 4b7a7d212
# Temos 7 amostras com a droga aeda2a606
# Temos 7 amostras com a droga de8fa84b4
# Temos 7 amostras com a droga 28879e19e
# Temos 7 amostras com a droga e3a88c3f3
# Temos 7 amostras com a droga b8bffd104
# Temos 7 amostras com a droga 6b27abb86
# Temos 7 amostras com a droga fa69a1fc0
# Temos 7 amostras com a droga f63b5512f
# Temos 7 amostras com a droga 79f6039a3
# Temos 7 amostras com a droga adabf11d3
# Temos 7 amostras com a droga ec02e96a8
# Temos 7 amostras com a droga 15da4702d
# Temos 7 amostras com a droga c27e6af6f
# Temos 7 amostras com a droga 4b8caf802
# Temos 7 amostras com a droga c9bc74fb3
# Temos 7 amostras com a droga abe3d3a3f
# Temos 7 amostras com a droga 9f31b00f7
# Temos 7 amostras com a droga 8e438ce43
# Temos 7 amostras com a droga 3b2bdd584
# Temos 7 amostras com a droga 2a4c67eba
# Temos 7 amostras com a droga c8763b2d3
# Temos 7 amostras com a droga 78a9ee6c5
# Temos 7 amostras com a droga 299460cf3
# Temos 6 amostras com a droga 32bd4cc74
# Temos 6 amostras com a droga cc96b78f2
# Temos 6 amostras com a droga 475c5fedb
# Temos 6 amostras com a droga 02084574f
# Temos 6 amostras com a droga 0a9da712c
# Temos 6 amostras com a droga 21f05d290
# Temos 6 amostras com a droga 1f7b51a4d
# Temos 6 amostras com a droga 994e6101b
# Temos 6 amostras com a droga 1a79afe73
# Temos 6 amostras com a droga fdf9c5a5d
# Temos 6 amostras com a droga bbfef20b7
# Temos 6 amostras com a droga da5f70b40
# Temos 6 amostras com a droga 29992b374
# Temos 6 amostras com a droga fe2ced8f1
# Temos 6 amostras com a droga c66c843e3
# Temos 6 amostras com a droga 7671d43c1
# Temos 6 amostras com a droga 721570a19
# Temos 6 amostras com a droga e75e2b61a
# Temos 6 amostras com a droga da7542ede
# Temos 6 amostras com a droga 1738d9092
# Temos 6 amostras com a droga 124e2dd9b
# Temos 6 amostras com a droga 6eb8ff3da
# Temos 6 amostras com a droga fa3500863
# Temos 6 amostras com a droga 7aaaab610
# Temos 6 amostras com a droga 29a240dd6
# Temos 6 amostras com a droga d4c515a95
# Temos 6 amostras com a droga a87d92c8b
# Temos 6 amostras com a droga 8fd979999
# Temos 6 amostras com a droga b67a81f96
# Temos 6 amostras com a droga a043e7bb8
# Temos 6 amostras com a droga 211b5a3d5
# Temos 6 amostras com a droga 8dad6ac60
# Temos 6 amostras com a droga f59d0edb4
# Temos 6 amostras com a droga a90ee8ca7
# Temos 6 amostras com a droga 63f43cb38
# Temos 6 amostras com a droga 96cba48b8
# Temos 6 amostras com a droga b96d23f70
# Temos 6 amostras com a droga 09dfe3a61
# Temos 6 amostras com a droga e99c149b5
# Temos 6 amostras com a droga e8f9bb247
# Temos 6 amostras com a droga d56702d3b
# Temos 6 amostras com a droga a5230817b
# Temos 6 amostras com a droga beb21d2bc
# Temos 6 amostras com a droga e7f466249
# Temos 6 amostras com a droga 30ec6afbc
# Temos 6 amostras com a droga 84d4ecc6a
# Temos 6 amostras com a droga 685a2dbd1
# Temos 6 amostras com a droga 9158344c4
# Temos 6 amostras com a droga cc702cc19
# Temos 6 amostras com a droga 1bce4a659
# Temos 6 amostras com a droga 79e6b524a
# Temos 6 amostras com a droga a3e52fcc0
# Temos 6 amostras com a droga 887c2e121
# Temos 6 amostras com a droga eb56effe8
# Temos 6 amostras com a droga cbf00dd7c
# Temos 6 amostras com a droga 0c697edf3
# Temos 6 amostras com a droga 7e569a33a
# Temos 6 amostras com a droga 4c397fd24
# Temos 6 amostras com a droga efa4a3106
# Temos 6 amostras com a droga ac7ea7c77
# Temos 6 amostras com a droga bc7aac3d2
# Temos 6 amostras com a droga 1cc61abd7
# Temos 6 amostras com a droga a994d4d9b
# Temos 6 amostras com a droga 3ee3c4f73
# Temos 6 amostras com a droga 16fc18110
# Temos 6 amostras com a droga c0417407c
# Temos 6 amostras com a droga 1493a1e86
# Temos 6 amostras com a droga 1b5be72dc
# Temos 6 amostras com a droga 9429c36f2
# Temos 6 amostras com a droga 329ac3519
# Temos 6 amostras com a droga e5b84d23b
# Temos 6 amostras com a droga 30ac46c44
# Temos 6 amostras com a droga 36ab4aaf7
# Temos 6 amostras com a droga b0e220a18
# Temos 6 amostras com a droga ecf3b6b74
# Temos 6 amostras com a droga 0d353a095
# Temos 6 amostras com a droga 29c8a163f
# Temos 6 amostras com a droga b471db129
# Temos 6 amostras com a droga 6333d8b74
# Temos 6 amostras com a droga 47324d95c
# Temos 6 amostras com a droga a14e0fa86
# Temos 6 amostras com a droga 705966243
# Temos 6 amostras com a droga e30dcf933
# Temos 6 amostras com a droga eecc6a289
# Temos 6 amostras com a droga 158113616
# Temos 6 amostras com a droga d59e2bf68
# Temos 6 amostras com a droga 9af8c1058
# Temos 6 amostras com a droga 561119c80
# Temos 6 amostras com a droga 592929e23
# Temos 6 amostras com a droga b016fdb77
# Temos 6 amostras com a droga d53f01057
# Temos 6 amostras com a droga 27998e50f
# Temos 6 amostras com a droga 7e33f1ac7
# Temos 6 amostras com a droga 9ff6e306f
# Temos 6 amostras com a droga 942553571
# Temos 6 amostras com a droga 82e9d6227
# Temos 6 amostras com a droga c1dab6039
# Temos 6 amostras com a droga 0869981c5
# Temos 6 amostras com a droga ba87a83c2
# Temos 6 amostras com a droga fcafcf5a9
# Temos 6 amostras com a droga 437a5bd76
# Temos 6 amostras com a droga 6c8ad2e0d
# Temos 6 amostras com a droga 6b039baf0
# Temos 6 amostras com a droga 926a489b1
# Temos 6 amostras com a droga fe7e9ab78
# Temos 6 amostras com a droga f4e4006d9
# Temos 6 amostras com a droga 49db5dad6
# Temos 6 amostras com a droga ed056dede
# Temos 6 amostras com a droga 8313e9d27
# Temos 6 amostras com a droga d767a14e3
# Temos 6 amostras com a droga d390fef44
# Temos 6 amostras com a droga f1766a962
# Temos 6 amostras com a droga ed85431dc
# Temos 6 amostras com a droga 42e5e3f31
# Temos 6 amostras com a droga f7fe1c12f
# Temos 6 amostras com a droga 7e7cf6909
# Temos 6 amostras com a droga d9404da1e
# Temos 6 amostras com a droga c2f720006
# Temos 6 amostras com a droga a214197e5
# Temos 6 amostras com a droga 90abb1f13
# Temos 6 amostras com a droga e9ce48593
# Temos 6 amostras com a droga 91360929a
# Temos 6 amostras com a droga 1bcab17e9
# Temos 6 amostras com a droga 6a4ad6b60
# Temos 6 amostras com a droga 87d4d4802
# Temos 6 amostras com a droga 100370c58
# Temos 6 amostras com a droga 2b52b677a
# Temos 6 amostras com a droga c6b500c21
# Temos 6 amostras com a droga 2a74be16e
# Temos 6 amostras com a droga 2925884c5
# Temos 6 amostras com a droga d58554765
# Temos 6 amostras com a droga 8acd33afb
# Temos 6 amostras com a droga 425a7f158
# Temos 6 amostras com a droga c44ab7c38
# Temos 6 amostras com a droga 1e2ab1d8c
# Temos 6 amostras com a droga 3bb4bf1e5
# Temos 6 amostras com a droga 4dcf18224
# Temos 6 amostras com a droga 6cd966644
# Temos 6 amostras com a droga 1b72f77e1
# Temos 6 amostras com a droga ec9e1ae6e
# Temos 6 amostras com a droga 1d9b3e2f3
# Temos 6 amostras com a droga eaf28d695
# Temos 6 amostras com a droga a115ee06e
# Temos 6 amostras com a droga 859aa3db7
# Temos 6 amostras com a droga bce9dc5c8
# Temos 6 amostras com a droga f8446fc97
# Temos 6 amostras com a droga 673a97299
# Temos 6 amostras com a droga 8bbb98105
# Temos 6 amostras com a droga 25cd3600b
# Temos 6 amostras com a droga 487085904
# Temos 6 amostras com a droga c451bb4cb
# Temos 6 amostras com a droga 175129f43
# Temos 6 amostras com a droga e45ad489d
# Temos 6 amostras com a droga 8f128b570
# Temos 6 amostras com a droga f7e6d1b90
# Temos 6 amostras com a droga 9bf0c9681
# Temos 6 amostras com a droga a12fba982
# Temos 6 amostras com a droga bc45ee7ed
# Temos 6 amostras com a droga f67915196
# Temos 6 amostras com a droga 5adcd38c7
# Temos 6 amostras com a droga f9450b58a
# Temos 6 amostras com a droga a1d43b20d
# Temos 6 amostras com a droga bd1ff4469
# Temos 6 amostras com a droga 591c4ee47
# Temos 6 amostras com a droga a5a285e3f
# Temos 6 amostras com a droga 8c48a42be
# Temos 6 amostras com a droga c5de6866e
# Temos 6 amostras com a droga b59817415
# Temos 6 amostras com a droga a17e63cf1
# Temos 6 amostras com a droga 4787e9cc1
# Temos 6 amostras com a droga d068b0638
# Temos 6 amostras com a droga 75794d149
# Temos 6 amostras com a droga 2964edfc8
# Temos 6 amostras com a droga 73c04bcc5
# Temos 6 amostras com a droga 6ed25f7d9
# Temos 6 amostras com a droga db406b2e6
# Temos 6 amostras com a droga 9cc1467b6
# Temos 6 amostras com a droga 35e552246
# Temos 6 amostras com a droga 05e9ef087
# Temos 6 amostras com a droga cbfaff9d1
# Temos 6 amostras com a droga 42800f350
# Temos 6 amostras com a droga 0b33c4d4b
# Temos 6 amostras com a droga 61ecd9a5b
# Temos 6 amostras com a droga 8374daa51
# Temos 6 amostras com a droga b6b3ee41d
# Temos 6 amostras com a droga 155a94eb7
# Temos 6 amostras com a droga 2284046f5
# Temos 6 amostras com a droga d0c38f6ff
# Temos 6 amostras com a droga 183c7e3f3
# Temos 6 amostras com a droga 182c3b858
# Temos 6 amostras com a droga b0c582a9c
# Temos 6 amostras com a droga 29b48a8b7
# Temos 6 amostras com a droga 15da14cfb
# Temos 6 amostras com a droga b12140550
# Temos 6 amostras com a droga 8c5413748
# Temos 6 amostras com a droga 1a892fd97
# Temos 6 amostras com a droga 73ba9ce58
# Temos 6 amostras com a droga b5886f4ee
# Temos 6 amostras com a droga 586aa4a46
# Temos 6 amostras com a droga c20801db6
# Temos 6 amostras com a droga c60e35d05
# Temos 6 amostras com a droga b2e18c9b7
# Temos 6 amostras com a droga 58f735145
# Temos 6 amostras com a droga bcc1eace2
# Temos 6 amostras com a droga 5d7696953
# Temos 6 amostras com a droga 6c1147903
# Temos 6 amostras com a droga b627b4156
# Temos 6 amostras com a droga 8791ef2ae
# Temos 6 amostras com a droga 67f1e7c58
# Temos 6 amostras com a droga 964888f81
# Temos 6 amostras com a droga 90f770ec6
# Temos 6 amostras com a droga 58684fff2
# Temos 6 amostras com a droga 9df803dd5
# Temos 6 amostras com a droga 4b893a449
# Temos 6 amostras com a droga 2997f7207
# Temos 6 amostras com a droga 352f26962
# Temos 6 amostras com a droga a354df2dc
# Temos 6 amostras com a droga 5dba7da37
# Temos 6 amostras com a droga 28f63043b
# Temos 6 amostras com a droga 7d50d31a6
# Temos 6 amostras com a droga 859076f27
# Temos 6 amostras com a droga dee1b775a
# Temos 6 amostras com a droga 88df04154
# Temos 6 amostras com a droga 3f472c8fb
# Temos 6 amostras com a droga 2e28d6c72
# Temos 6 amostras com a droga dd0ce6221
# Temos 6 amostras com a droga c6cc9175b
# Temos 6 amostras com a droga 9289a3800
# Temos 6 amostras com a droga afed0fc6d
# Temos 6 amostras com a droga 2ab816414
# Temos 6 amostras com a droga 6597149ef
# Temos 6 amostras com a droga b369dab76
# Temos 6 amostras com a droga d1681e2ff
# Temos 6 amostras com a droga dc90108c3
# Temos 6 amostras com a droga 0672af23e
# Temos 6 amostras com a droga 5ab704064
# Temos 6 amostras com a droga 9b87ce240
# Temos 6 amostras com a droga d870d8287
# Temos 6 amostras com a droga cb01ff9d8
# Temos 6 amostras com a droga b077801cd
# Temos 6 amostras com a droga c5d69a751
# Temos 6 amostras com a droga 053b1881a
# Temos 6 amostras com a droga 9e9c9ce56
# Temos 6 amostras com a droga 7574c566b
# Temos 6 amostras com a droga 48b540088
# Temos 6 amostras com a droga ccad8d70f
# Temos 6 amostras com a droga b9f7f3b59
# Temos 6 amostras com a droga d76d29c86
# Temos 6 amostras com a droga b45e6832d
# Temos 6 amostras com a droga 4c6103a90
# Temos 6 amostras com a droga d66f0ffb7
# Temos 6 amostras com a droga c43ed9969
# Temos 6 amostras com a droga 505d0ef8e
# Temos 6 amostras com a droga ac2e68607
# Temos 6 amostras com a droga 85cc76a9f
# Temos 6 amostras com a droga c0560ba98
# Temos 6 amostras com a droga b76f50e48
# Temos 6 amostras com a droga 235333326
# Temos 6 amostras com a droga f3f77dac0
# Temos 6 amostras com a droga 10e1e8563
# Temos 6 amostras com a droga eacee102c
# Temos 6 amostras com a droga c4cfe5f72
# Temos 6 amostras com a droga b5facfcb6
# Temos 6 amostras com a droga c0642cc5a
# Temos 6 amostras com a droga 7343524ec
# Temos 6 amostras com a droga 212446fb4
# Temos 6 amostras com a droga d074c17a3
# Temos 6 amostras com a droga 650c0ae52
# Temos 6 amostras com a droga 911e358b7
# Temos 6 amostras com a droga d144a991c
# Temos 6 amostras com a droga bac4b7207
# Temos 6 amostras com a droga 9dc2848e0
# Temos 6 amostras com a droga 95b087f23
# Temos 6 amostras com a droga 8d31a1d0a
# Temos 6 amostras com a droga bbd36745d
# Temos 6 amostras com a droga 987f5f004
# Temos 6 amostras com a droga 7f0a7be43
# Temos 6 amostras com a droga f4c0acb6b
# Temos 6 amostras com a droga 81bf9fb8c
# Temos 6 amostras com a droga fcc0d5d89
# Temos 6 amostras com a droga 4c42f8d6f
# Temos 6 amostras com a droga 7d2c7255a
# Temos 6 amostras com a droga e80240e24
# Temos 6 amostras com a droga f769df5d6
# Temos 6 amostras com a droga 54d869553
# Temos 6 amostras com a droga fc9706723
# Temos 6 amostras com a droga 16c3d3bee
# Temos 6 amostras com a droga e6cd1235b
# Temos 6 amostras com a droga e2b513d9a
# Temos 6 amostras com a droga c5388f6a0
# Temos 6 amostras com a droga 06b61c0ea
# Temos 6 amostras com a droga 2e26b4605
# Temos 6 amostras com a droga ffd66e220
# Temos 6 amostras com a droga 972f41291
# Temos 6 amostras com a droga fb5164119
# Temos 6 amostras com a droga 297219c32
# Temos 6 amostras com a droga 640db04b0
# Temos 6 amostras com a droga c3b5cac71
# Temos 6 amostras com a droga 80dbae6e2
# Temos 6 amostras com a droga f4a0da844
# Temos 6 amostras com a droga baf38e303
# Temos 6 amostras com a droga d0d0d9885
# Temos 6 amostras com a droga 3702115d8
# Temos 6 amostras com a droga 059eeaab7
# Temos 6 amostras com a droga 1c21f7ca7
# Temos 6 amostras com a droga 0472f88f4
# Temos 6 amostras com a droga 721df760a
# Temos 6 amostras com a droga 9c9b4e56a
# Temos 6 amostras com a droga df994947f
# Temos 6 amostras com a droga c5b400b1f
# Temos 6 amostras com a droga 81828c953
# Temos 6 amostras com a droga ba9f99c9c
# Temos 6 amostras com a droga 46ada8311
# Temos 6 amostras com a droga f487e1a2c
# Temos 6 amostras com a droga 62ad50147
# Temos 6 amostras com a droga 8709517b7
# Temos 6 amostras com a droga 9cce94064
# Temos 6 amostras com a droga 520c29eff
# Temos 6 amostras com a droga 9ffc1c082
# Temos 6 amostras com a droga 346c01544
# Temos 6 amostras com a droga 3e6b4e4cb
# Temos 6 amostras com a droga 64faf6255
# Temos 6 amostras com a droga e86f171c7
# Temos 6 amostras com a droga ac4d7be36
# Temos 6 amostras com a droga c18a180cf
# Temos 6 amostras com a droga a6c49d7e9
# Temos 6 amostras com a droga 009a5da05
# Temos 6 amostras com a droga 094f11f46
# Temos 6 amostras com a droga a180cec12
# Temos 6 amostras com a droga 67bb07b93
# Temos 6 amostras com a droga 2a61705dd
# Temos 6 amostras com a droga cafd478f9
# Temos 6 amostras com a droga 6a834c77e
# Temos 6 amostras com a droga c3d24fae4
# Temos 6 amostras com a droga 517ba49c1
# Temos 6 amostras com a droga 06af533b3
# Temos 6 amostras com a droga ad0701753
# Temos 6 amostras com a droga 827cc5d8d
# Temos 6 amostras com a droga 28a15cf13
# Temos 6 amostras com a droga 4c99cf19e
# Temos 6 amostras com a droga 031afe482
# Temos 6 amostras com a droga b41d21dbe
# Temos 6 amostras com a droga 7d5dafb2e
# Temos 6 amostras com a droga d7b50861a
# Temos 6 amostras com a droga 7902ac373
# Temos 6 amostras com a droga 9cf0df213
# Temos 6 amostras com a droga 3820146d1
# Temos 6 amostras com a droga 6e986ee5c
# Temos 6 amostras com a droga b7ec107f4
# Temos 6 amostras com a droga 5b07bdf86
# Temos 6 amostras com a droga 032128cc7
# Temos 6 amostras com a droga 3f0bd259a
# Temos 6 amostras com a droga 20d248d52
# Temos 6 amostras com a droga cf5db49f4
# Temos 6 amostras com a droga 956c3b5da
# Temos 6 amostras com a droga cdae2ebbf
# Temos 6 amostras com a droga 22f943d8d
# Temos 6 amostras com a droga 1b972d4e6
# Temos 6 amostras com a droga 122f493a7
# Temos 6 amostras com a droga 88a7e73c1
# Temos 6 amostras com a droga d714283f3
# Temos 6 amostras com a droga 9d5a1c5c1
# Temos 6 amostras com a droga 9ac88657a
# Temos 6 amostras com a droga f342eedbc
# Temos 6 amostras com a droga 1e1354bb0
# Temos 6 amostras com a droga c95a5ea9c
# Temos 6 amostras com a droga f17c382a6
# Temos 6 amostras com a droga 2aeb62161
# Temos 6 amostras com a droga d289bdd81
# Temos 6 amostras com a droga 0a7a2361d
# Temos 6 amostras com a droga 2e25f2ddb
# Temos 6 amostras com a droga 1371ab7d1
# Temos 6 amostras com a droga e8308db24
# Temos 6 amostras com a droga 8afd4ded9
# Temos 6 amostras com a droga 668260b02
# Temos 6 amostras com a droga 3c6a6673a
# Temos 6 amostras com a droga 42591280c
# Temos 6 amostras com a droga 8b75bfb1b
# Temos 6 amostras com a droga 6c85eef96
# Temos 6 amostras com a droga f0997edc7
# Temos 6 amostras com a droga 52bb1fe11
# Temos 6 amostras com a droga e75e1b3e0
# Temos 6 amostras com a droga ab3f5b53b
# Temos 6 amostras com a droga da4ee3d51
# Temos 6 amostras com a droga c720fdd23
# Temos 6 amostras com a droga ea17d0e03
# Temos 6 amostras com a droga 6a8e97963
# Temos 6 amostras com a droga cb462e5c6
# Temos 6 amostras com a droga b2f9c1483
# Temos 6 amostras com a droga f9a72fa7b
# Temos 6 amostras com a droga 38c7052a2
# Temos 6 amostras com a droga d8e2abc0f
# Temos 6 amostras com a droga c862a0e7a
# Temos 6 amostras com a droga 8faa855a9
# Temos 6 amostras com a droga e17c7275e
# Temos 6 amostras com a droga e41f6c48c
# Temos 6 amostras com a droga bfb333204
# Temos 6 amostras com a droga 0f7cd09d2
# Temos 6 amostras com a droga 4b23ef6df
# Temos 6 amostras com a droga 26a49c7f8
# Temos 6 amostras com a droga 532588621
# Temos 6 amostras com a droga c7304d3bd
# Temos 6 amostras com a droga 2c0916417
# Temos 6 amostras com a droga 29140d496
# Temos 6 amostras com a droga 474256f71
# Temos 6 amostras com a droga d8af76b75
# Temos 6 amostras com a droga 2a8f1a1e6
# Temos 6 amostras com a droga b70b5a087
# Temos 6 amostras com a droga d1cfb9885
# Temos 6 amostras com a droga 240f5b164
# Temos 6 amostras com a droga 2905ae5c4
# Temos 6 amostras com a droga c8ce35de9
# Temos 6 amostras com a droga 94bd65e9a
# Temos 6 amostras com a droga 71b4d9775
# Temos 6 amostras com a droga 427005627
# Temos 6 amostras com a droga 56b0af64b
# Temos 6 amostras com a droga c27545fd6
# Temos 6 amostras com a droga dd1bef73f
# Temos 6 amostras com a droga 0d3eea33f
# Temos 6 amostras com a droga 31d1b5808
# Temos 6 amostras com a droga d449fda32
# Temos 6 amostras com a droga 2294112df
# Temos 6 amostras com a droga 76c231fa8
# Temos 6 amostras com a droga a572d85d8
# Temos 6 amostras com a droga fc19979b0
# Temos 6 amostras com a droga d8b1403bc
# Temos 6 amostras com a droga df29b7f17
# Temos 6 amostras com a droga 04f5356dc
# Temos 6 amostras com a droga 34e85fe9d
# Temos 6 amostras com a droga fa4e8a8cf
# Temos 6 amostras com a droga 08ef97d85
# Temos 6 amostras com a droga 123bbd8c9
# Temos 6 amostras com a droga 201cdcec8
# Temos 6 amostras com a droga 96b9ac123
# Temos 6 amostras com a droga 8da60807e
# Temos 6 amostras com a droga 8e369b046
# Temos 6 amostras com a droga c9a4e1d37
# Temos 6 amostras com a droga ed092dc8d
# Temos 6 amostras com a droga e9b5faf16
# Temos 6 amostras com a droga 9a4775f71
# Temos 6 amostras com a droga 667f6e292
# Temos 6 amostras com a droga 00898e82c
# Temos 6 amostras com a droga e8f0cccd6
# Temos 6 amostras com a droga cbd1e5bae
# Temos 6 amostras com a droga 1ac3046e2
# Temos 6 amostras com a droga 1f9677293
# Temos 6 amostras com a droga 957aaf61f
# Temos 6 amostras com a droga 28a7c8b62
# Temos 6 amostras com a droga 00199ff52
# Temos 6 amostras com a droga 19aae2313
# Temos 6 amostras com a droga 8b292f993
# Temos 6 amostras com a droga ab6e8a3f1
# Temos 6 amostras com a droga d870792b9
# Temos 6 amostras com a droga d52e70ed4
# Temos 6 amostras com a droga 68b8c1d2c
# Temos 6 amostras com a droga 78bb32811
# Temos 6 amostras com a droga f75db62d4
# Temos 6 amostras com a droga 56ea83da7
# Temos 6 amostras com a droga 14c4be770
# Temos 6 amostras com a droga 80f09571d
# Temos 6 amostras com a droga a4a6aef68
# Temos 6 amostras com a droga 2bfc1246c
# Temos 6 amostras com a droga 6e4791c3a
# Temos 6 amostras com a droga 6b06d32ba
# Temos 6 amostras com a droga b59f2c4a2
# Temos 6 amostras com a droga a1a7000c4
# Temos 6 amostras com a droga 8f19f8d8b
# Temos 6 amostras com a droga c25d6dd1f
# Temos 6 amostras com a droga 74741b81b
# Temos 6 amostras com a droga de1269ab3
# Temos 6 amostras com a droga 8f928e97e
# Temos 6 amostras com a droga 5e73bee71
# Temos 6 amostras com a droga e9b1fef88
# Temos 6 amostras com a droga 883a08d7c
# Temos 6 amostras com a droga 03b86deca
# Temos 6 amostras com a droga f8bdaa4d4
# Temos 6 amostras com a droga e40153dde
# Temos 6 amostras com a droga 8458bb23d
# Temos 6 amostras com a droga c15da1022
# Temos 6 amostras com a droga 3a8369e1d
# Temos 6 amostras com a droga 4eca10c76
# Temos 6 amostras com a droga e1efce54c
# Temos 6 amostras com a droga 4c33b6fa1
# Temos 6 amostras com a droga d98786e51
# Temos 6 amostras com a droga 8c7b401c2
# Temos 6 amostras com a droga 86c4f8987
# Temos 6 amostras com a droga bf37a2d6a
# Temos 6 amostras com a droga 80a578224
# Temos 6 amostras com a droga 798bc9f3c
# Temos 6 amostras com a droga e6cd67235
# Temos 6 amostras com a droga 8525f258f
# Temos 6 amostras com a droga 13c8854af
# Temos 6 amostras com a droga 44861c09d
# Temos 6 amostras com a droga 2830d3cb4
# Temos 6 amostras com a droga 77ca07d42
# Temos 6 amostras com a droga 2bad1b4f2
# Temos 6 amostras com a droga 6523ad4c8
# Temos 6 amostras com a droga d2d29e48f
# Temos 6 amostras com a droga 72e97bc09
# Temos 6 amostras com a droga 74e15b46d
# Temos 6 amostras com a droga f66a2c5aa
# Temos 6 amostras com a droga 19952d3be
# Temos 6 amostras com a droga 6125952bb
# Temos 6 amostras com a droga a61df3fa9
# Temos 6 amostras com a droga 49bd142d9
# Temos 6 amostras com a droga 8ee60a3e0
# Temos 6 amostras com a droga c058ab538
# Temos 6 amostras com a droga 7614ec763
# Temos 6 amostras com a droga feaadfd38
# Temos 6 amostras com a droga 8b82937f6
# Temos 6 amostras com a droga aa8c877e3
# Temos 6 amostras com a droga fe213e3a3
# Temos 6 amostras com a droga 6c665f098
# Temos 6 amostras com a droga 6e9a63153
# Temos 6 amostras com a droga df190d2b7
# Temos 6 amostras com a droga fe37066fc
# Temos 6 amostras com a droga 6ddb71abd
# Temos 6 amostras com a droga 6c3a8ced5
# Temos 6 amostras com a droga dd73b5345
# Temos 6 amostras com a droga dd30eef7a
# Temos 6 amostras com a droga cc305f73c
# Temos 6 amostras com a droga 55507f2c1
# Temos 6 amostras com a droga c70861396
# Temos 6 amostras com a droga a9d14dd13
# Temos 6 amostras com a droga a95ca4f7d
# Temos 6 amostras com a droga 88d508490
# Temos 6 amostras com a droga cbbb2153d
# Temos 6 amostras com a droga 3d4298d4a
# Temos 6 amostras com a droga ff9565933
# Temos 6 amostras com a droga 08e555b5d
# Temos 6 amostras com a droga 5a13d6c2c
# Temos 6 amostras com a droga 8d26b9118
# Temos 6 amostras com a droga 28a834f70
# Temos 6 amostras com a droga 9f907fcd6
# Temos 6 amostras com a droga 807e10282
# Temos 6 amostras com a droga 7d6e641dd
# Temos 6 amostras com a droga fc61cc291
# Temos 6 amostras com a droga 780f7e833
# Temos 6 amostras com a droga fc9cc6ec4
# Temos 6 amostras com a droga ed4c86647
# Temos 6 amostras com a droga 95686e7fa
# Temos 6 amostras com a droga 9a52a0142
# Temos 6 amostras com a droga 431a59ec3
# Temos 6 amostras com a droga 0ddc8c8dd
# Temos 6 amostras com a droga 3f60092bc
# Temos 6 amostras com a droga 6d365d473
# Temos 6 amostras com a droga 83d61e159
# Temos 6 amostras com a droga ca8387b14
# Temos 6 amostras com a droga 5f146f9eb
# Temos 6 amostras com a droga 2cfa96d20
# Temos 6 amostras com a droga b2bda17d8
# Temos 6 amostras com a droga ab265c296
# Temos 6 amostras com a droga fd68e0363
# Temos 6 amostras com a droga 228f08c3d
# Temos 6 amostras com a droga 3cdc48274
# Temos 6 amostras com a droga 0d3228a10
# Temos 6 amostras com a droga e6133b664
# Temos 6 amostras com a droga 47790ff22
# Temos 6 amostras com a droga 1da08b29e
# Temos 6 amostras com a droga 673c67b84
# Temos 6 amostras com a droga 3e5ede2f6
# Temos 6 amostras com a droga ea6a9bd66
# Temos 6 amostras com a droga 172ce511a
# Temos 6 amostras com a droga 33c90bb0b
# Temos 6 amostras com a droga 50cd26ac2
# Temos 6 amostras com a droga 63ffa9918
# Temos 6 amostras com a droga aed4e4afb
# Temos 6 amostras com a droga 483b8fd13
# Temos 6 amostras com a droga 66dc0685e
# Temos 6 amostras com a droga 270fbca20
# Temos 6 amostras com a droga 6f4c937c6
# Temos 6 amostras com a droga edfc36f0e
# Temos 6 amostras com a droga bbae00d6d
# Temos 6 amostras com a droga 99017a2c7
# Temos 6 amostras com a droga d219a0018
# Temos 6 amostras com a droga 26b98a417
# Temos 6 amostras com a droga 5bc490161
# Temos 6 amostras com a droga cedcfd30a
# Temos 6 amostras com a droga d3b0064d0
# Temos 6 amostras com a droga a2bc2d048
# Temos 6 amostras com a droga 191bfe656
# Temos 6 amostras com a droga 071afe3da
# Temos 6 amostras com a droga d30573f2e
# Temos 6 amostras com a droga 8648dfe09
# Temos 6 amostras com a droga 88a421c74
# Temos 6 amostras com a droga 4a93cfbbb
# Temos 6 amostras com a droga 755d4d0c1
# Temos 6 amostras com a droga 7cbed3131
# Temos 6 amostras com a droga 0691eefdd
# Temos 6 amostras com a droga 2493e7197
# Temos 6 amostras com a droga 1f5dc16e1
# Temos 6 amostras com a droga 70a8cfb4f
# Temos 6 amostras com a droga ab2e02e76
# Temos 6 amostras com a droga e9fc1a8ac
# Temos 6 amostras com a droga 6c1dc8477
# Temos 6 amostras com a droga e71f3a8b8
# Temos 6 amostras com a droga 32667f5be
# Temos 6 amostras com a droga a6e8b2e70
# Temos 6 amostras com a droga 226072171
# Temos 6 amostras com a droga 3a904cbae
# Temos 6 amostras com a droga e479d920b
# Temos 6 amostras com a droga fb559ed55
# Temos 6 amostras com a droga 81756e31a
# Temos 6 amostras com a droga e39f7a3d9
# Temos 6 amostras com a droga b482d5c23
# Temos 6 amostras com a droga d65a23889
# Temos 6 amostras com a droga 17e32e2ca
# Temos 6 amostras com a droga 8a16bd4c6
# Temos 6 amostras com a droga e3d9d000d
# Temos 6 amostras com a droga 66f13dd14
# Temos 6 amostras com a droga 966f02f06
# Temos 6 amostras com a droga 620a76eb1
# Temos 6 amostras com a droga c957f6ac7
# Temos 6 amostras com a droga 62ff1ff60
# Temos 6 amostras com a droga b51c84690
# Temos 6 amostras com a droga 690c67f98
# Temos 6 amostras com a droga d2991f386
# Temos 6 amostras com a droga 6e6a1d184
# Temos 6 amostras com a droga f0ae14edc
# Temos 6 amostras com a droga 48f7eba68
# Temos 6 amostras com a droga df26c5aa0
# Temos 6 amostras com a droga 99f8a66ae
# Temos 6 amostras com a droga ee919977f
# Temos 6 amostras com a droga a551574a7
# Temos 6 amostras com a droga 654b180f8
# Temos 6 amostras com a droga b99b631e2
# Temos 6 amostras com a droga 355e0b5ca
# Temos 6 amostras com a droga 6af52e87e
# Temos 6 amostras com a droga 94e531807
# Temos 6 amostras com a droga 3f7f6b800
# Temos 6 amostras com a droga 2352c6333
# Temos 6 amostras com a droga a68423cff
# Temos 6 amostras com a droga 96e24fca6
# Temos 6 amostras com a droga 9335516ff
# Temos 6 amostras com a droga 82dee97da
# Temos 6 amostras com a droga b81934957
# Temos 6 amostras com a droga dd4e3bd8e
# Temos 6 amostras com a droga 0fb911637
# Temos 6 amostras com a droga ed4e951ad
# Temos 6 amostras com a droga 62a1142b7
# Temos 6 amostras com a droga bd8a2b7eb
# Temos 6 amostras com a droga e994cfd02
# Temos 6 amostras com a droga 9661459bc
# Temos 6 amostras com a droga d46d06ed5
# Temos 6 amostras com a droga 97c5016a2
# Temos 6 amostras com a droga 3f5098e6a
# Temos 6 amostras com a droga 07ab9d694
# Temos 6 amostras com a droga 0ebfd755d
# Temos 6 amostras com a droga 3cc579952
# Temos 6 amostras com a droga 931ae30d5
# Temos 6 amostras com a droga 40bfdfbb7
# Temos 6 amostras com a droga bb7bcdbc2
# Temos 6 amostras com a droga 7ec99cbab
# Temos 6 amostras com a droga 45d1a70c4
# Temos 6 amostras com a droga ed5706da4
# Temos 6 amostras com a droga 70b0e57f1
# Temos 6 amostras com a droga 7eebca46e
# Temos 6 amostras com a droga 661a4dd2f
# Temos 6 amostras com a droga b6410b8e1
# Temos 6 amostras com a droga c34e4424f
# Temos 6 amostras com a droga ea2734432
# Temos 6 amostras com a droga 34f1b60c1
# Temos 6 amostras com a droga f96caffcb
# Temos 6 amostras com a droga 408ac68a0
# Temos 6 amostras com a droga a1f8fe095
# Temos 6 amostras com a droga 986f762a1
# Temos 6 amostras com a droga f332d21c7
# Temos 6 amostras com a droga 248a98dcc
# Temos 6 amostras com a droga bb3e8a4f7
# Temos 6 amostras com a droga 91beddbbc
# Temos 6 amostras com a droga 15fcb2fab
# Temos 6 amostras com a droga b130d5c91
# Temos 6 amostras com a droga 779b92f1c
# Temos 6 amostras com a droga b07818506
# Temos 6 amostras com a droga 14f536e5c
# Temos 6 amostras com a droga 58c0f7a88
# Temos 6 amostras com a droga f0b593426
# Temos 6 amostras com a droga abec24ea6
# Temos 6 amostras com a droga b62e815c1
# Temos 6 amostras com a droga 0818cea28
# Temos 6 amostras com a droga 2ba00bf6e
# Temos 6 amostras com a droga c113d21eb
# Temos 6 amostras com a droga f2e39846a
# Temos 6 amostras com a droga 535f7a0e6
# Temos 6 amostras com a droga f721996ed
# Temos 6 amostras com a droga eac5c838f
# Temos 6 amostras com a droga b1b429d55
# Temos 6 amostras com a droga 6adcb05b2
# Temos 6 amostras com a droga 8627a9ea2
# Temos 6 amostras com a droga cbe28733a
# Temos 6 amostras com a droga af3aa3a26
# Temos 6 amostras com a droga a679b6ae7
# Temos 6 amostras com a droga 2a3172400
# Temos 6 amostras com a droga d8768202c
# Temos 6 amostras com a droga b5217f49a
# Temos 6 amostras com a droga 4b82a8056
# Temos 6 amostras com a droga 9ddeb8b52
# Temos 6 amostras com a droga b9e3cb10b
# Temos 6 amostras com a droga db50e7c67
# Temos 6 amostras com a droga adf8b6ead
# Temos 6 amostras com a droga 32585ca0c
# Temos 6 amostras com a droga 5ee773734
# Temos 6 amostras com a droga 75ad700d0
# Temos 6 amostras com a droga bff233aaf
# Temos 6 amostras com a droga ffed8e1c9
# Temos 6 amostras com a droga 4bf26b765
# Temos 6 amostras com a droga b877aa048
# Temos 6 amostras com a droga 227dac617
# Temos 6 amostras com a droga 21873d192
# Temos 6 amostras com a droga ff539cce7
# Temos 6 amostras com a droga 8c25111b8
# Temos 6 amostras com a droga d9373049c
# Temos 6 amostras com a droga 5f326dadb
# Temos 6 amostras com a droga 70e371c71
# Temos 6 amostras com a droga 90bf1a888
# Temos 6 amostras com a droga 6509a4c73
# Temos 6 amostras com a droga 78db88217
# Temos 6 amostras com a droga bd2140972
# Temos 6 amostras com a droga 9b0fa2676
# Temos 6 amostras com a droga dfde88183
# Temos 6 amostras com a droga 09d2dafc9
# Temos 6 amostras com a droga 0eae9401c
# Temos 6 amostras com a droga 3c39c920a
# Temos 6 amostras com a droga 3226ca64a
# Temos 6 amostras com a droga 93d2e301a
# Temos 6 amostras com a droga db6b74f08
# Temos 6 amostras com a droga 5b4c20c9e
# Temos 6 amostras com a droga ce7077c0d
# Temos 6 amostras com a droga 3d08fafe8
# Temos 6 amostras com a droga 32bad50f4
# Temos 6 amostras com a droga 55b20e5c2
# Temos 6 amostras com a droga 6ae801d3b
# Temos 6 amostras com a droga d82e75aa7
# Temos 6 amostras com a droga d4c998587
# Temos 6 amostras com a droga e4dd7268c
# Temos 6 amostras com a droga 41267bb69
# Temos 6 amostras com a droga 924c9bb02
# Temos 6 amostras com a droga 9743b41f4
# Temos 6 amostras com a droga 984bc762c
# Temos 6 amostras com a droga 9684693b8
# Temos 6 amostras com a droga a226e91f9
# Temos 6 amostras com a droga 7980a0266
# Temos 6 amostras com a droga 6fb701ca1
# Temos 6 amostras com a droga 1ea8cd37d
# Temos 6 amostras com a droga 6a73f4bc7
# Temos 6 amostras com a droga ad42010b1
# Temos 6 amostras com a droga 2701543aa
# Temos 6 amostras com a droga 8e99eca56
# Temos 6 amostras com a droga 7e6ba019e
# Temos 6 amostras com a droga 60fb1a2e9
# Temos 6 amostras com a droga f35dc494f
# Temos 6 amostras com a droga 5db1c69e6
# Temos 6 amostras com a droga b82c2dad0
# Temos 6 amostras com a droga 44312df3f
# Temos 6 amostras com a droga 75e7d9739
# Temos 6 amostras com a droga 1404f95d7
# Temos 6 amostras com a droga 2e1874900
# Temos 6 amostras com a droga 269cfe6ea
# Temos 6 amostras com a droga 9ab3a6c42
# Temos 6 amostras com a droga 2fc2852b3
# Temos 6 amostras com a droga 49cea36e7
# Temos 6 amostras com a droga c46bdbc3b
# Temos 6 amostras com a droga e07f26e20
# Temos 6 amostras com a droga ea039e7b3
# Temos 6 amostras com a droga a4e7d9c48
# Temos 6 amostras com a droga fdf3069d4
# Temos 6 amostras com a droga b683db2f8
# Temos 6 amostras com a droga adb0c3173
# Temos 6 amostras com a droga 0e430527f
# Temos 6 amostras com a droga 09f1ecae4
# Temos 6 amostras com a droga 55f6ec3b4
# Temos 6 amostras com a droga eb98dcd19
# Temos 6 amostras com a droga b5c650a89
# Temos 6 amostras com a droga a6854318d
# Temos 6 amostras com a droga 04765e596
# Temos 6 amostras com a droga 5778f608a
# Temos 6 amostras com a droga 73ab19cc6
# Temos 6 amostras com a droga ea688452f
# Temos 6 amostras com a droga 8ce4ff1d6
# Temos 6 amostras com a droga c70a353c8
# Temos 6 amostras com a droga a5e5002ef
# Temos 6 amostras com a droga 54df97bc5
# Temos 6 amostras com a droga 92d4d3daa
# Temos 6 amostras com a droga 7f8f99f1b
# Temos 6 amostras com a droga 3db193b3b
# Temos 6 amostras com a droga 482308b86
# Temos 6 amostras com a droga f22c8afa0
# Temos 6 amostras com a droga e11b783c0
# Temos 6 amostras com a droga e4c68cd75
# Temos 6 amostras com a droga 01872549f
# Temos 6 amostras com a droga b556d4383
# Temos 6 amostras com a droga 42cf06e23
# Temos 6 amostras com a droga bf313303a
# Temos 6 amostras com a droga 232d3e660
# Temos 6 amostras com a droga 4c77094c0
# Temos 6 amostras com a droga 99d524de4
# Temos 6 amostras com a droga e884dc1e8
# Temos 6 amostras com a droga b61bae7f5
# Temos 6 amostras com a droga a404bf959
# Temos 6 amostras com a droga be944f78a
# Temos 6 amostras com a droga 94255bcc3
# Temos 6 amostras com a droga 2eb7fc8f3
# Temos 6 amostras com a droga 1d04eaf44
# Temos 6 amostras com a droga 6fc11b2c5
# Temos 6 amostras com a droga 2b630dd70
# Temos 6 amostras com a droga c6b490579
# Temos 6 amostras com a droga 0aa0cd705
# Temos 6 amostras com a droga 6609f523a
# Temos 6 amostras com a droga 80ea3c823
# Temos 6 amostras com a droga 7ea17588b
# Temos 6 amostras com a droga a1976a4b8
# Temos 6 amostras com a droga cf071c439
# Temos 6 amostras com a droga 9ffde3b1b
# Temos 6 amostras com a droga d201bb3e9
# Temos 6 amostras com a droga 8b52661f8
# Temos 6 amostras com a droga 2fb591d53
# Temos 6 amostras com a droga cf505fa7f
# Temos 6 amostras com a droga 2d753cbed
# Temos 6 amostras com a droga b3ab49180
# Temos 6 amostras com a droga 3fc86d9c1
# Temos 6 amostras com a droga 366cfd589
# Temos 6 amostras com a droga de6954488
# Temos 6 amostras com a droga 291b86a26
# Temos 6 amostras com a droga a39ce96c9
# Temos 6 amostras com a droga 2c804aab1
# Temos 6 amostras com a droga e2eb1a821
# Temos 6 amostras com a droga 74b133579
# Temos 6 amostras com a droga a50b64b31
# Temos 6 amostras com a droga 5cb1e784b
# Temos 6 amostras com a droga ad8a9c45d
# Temos 6 amostras com a droga 511f19724
# Temos 6 amostras com a droga 34a1356e1
# Temos 6 amostras com a droga bb5876e3e
# Temos 6 amostras com a droga ae3761091
# Temos 6 amostras com a droga af488380b
# Temos 6 amostras com a droga 6c3f1fb45
# Temos 6 amostras com a droga 82fd56cd7
# Temos 6 amostras com a droga 81be51c8c
# Temos 6 amostras com a droga 4c5736ff6
# Temos 6 amostras com a droga d3a86129b
# Temos 6 amostras com a droga fcb7bf70f
# Temos 6 amostras com a droga 17490f218
# Temos 6 amostras com a droga 581946f04
# Temos 6 amostras com a droga 7446347d4
# Temos 6 amostras com a droga 7e7dfcf43
# Temos 6 amostras com a droga d60045956
# Temos 6 amostras com a droga 2cc6e68ef
# Temos 6 amostras com a droga d681d223e
# Temos 6 amostras com a droga fedd79674
# Temos 6 amostras com a droga f5f05bec7
# Temos 6 amostras com a droga d22b4e6d9
# Temos 6 amostras com a droga ef8863aaf
# Temos 6 amostras com a droga 3851faee1
# Temos 6 amostras com a droga 4e2f4d81b
# Temos 6 amostras com a droga 174dbc4c7
# Temos 6 amostras com a droga aed11ae9b
# Temos 6 amostras com a droga 497160e06
# Temos 6 amostras com a droga 23ffb25a4
# Temos 6 amostras com a droga 89dbaa298
# Temos 6 amostras com a droga e321de4e1
# Temos 6 amostras com a droga 06c3860e2
# Temos 6 amostras com a droga 8d43856e0
# Temos 6 amostras com a droga 6aebeddc6
# Temos 6 amostras com a droga 8e6a6f400
# Temos 6 amostras com a droga b850ca8ed
# Temos 6 amostras com a droga 914d07573
# Temos 6 amostras com a droga 84d5fe2e8
# Temos 6 amostras com a droga 099d52518
# Temos 6 amostras com a droga 157d90b1f
# Temos 6 amostras com a droga f622c0642
# Temos 6 amostras com a droga 2cd098f33
# Temos 6 amostras com a droga da6bec758
# Temos 6 amostras com a droga 226348f20
# Temos 6 amostras com a droga cd4f7ec46
# Temos 6 amostras com a droga 467d5ebde
# Temos 6 amostras com a droga 40accea77
# Temos 6 amostras com a droga 45792bf48
# Temos 6 amostras com a droga 5e6f37c30
# Temos 6 amostras com a droga 273ff6a56
# Temos 6 amostras com a droga 252bf6e2a
# Temos 6 amostras com a droga c1617c18b
# Temos 6 amostras com a droga aef80fc76
# Temos 6 amostras com a droga 991b96cb6
# Temos 6 amostras com a droga c31e5bfad
# Temos 6 amostras com a droga 12a367c0e
# Temos 6 amostras com a droga 28dd9636a
# Temos 6 amostras com a droga f8dc1fd51
# Temos 6 amostras com a droga 8a51a2ef0
# Temos 6 amostras com a droga be94ae2b9
# Temos 6 amostras com a droga 38a70d0e1
# Temos 6 amostras com a droga c4ed464f2
# Temos 6 amostras com a droga c37bffc74
# Temos 6 amostras com a droga 35deba05e
# Temos 6 amostras com a droga 7cc96121b
# Temos 6 amostras com a droga 733a149a4
# Temos 6 amostras com a droga c36a35183
# Temos 6 amostras com a droga 2a5a539a0
# Temos 6 amostras com a droga 697cb2e39
# Temos 6 amostras com a droga 639ad146a
# Temos 6 amostras com a droga 39b5b0061
# Temos 6 amostras com a droga 366bf0132
# Temos 6 amostras com a droga a393c6f69
# Temos 6 amostras com a droga 53767c7d8
# Temos 6 amostras com a droga 608a0a4eb
# Temos 6 amostras com a droga 2ad4f79fd
# Temos 6 amostras com a droga 729f3ce84
# Temos 6 amostras com a droga d43ece694
# Temos 6 amostras com a droga 8689b5677
# Temos 6 amostras com a droga f2c8faae3
# Temos 6 amostras com a droga e62689392
# Temos 6 amostras com a droga 979f3480e
# Temos 6 amostras com a droga 0838d5330
# Temos 6 amostras com a droga 75a812849
# Temos 6 amostras com a droga 7c161c5dd
# Temos 6 amostras com a droga 85cebfb8d
# ...
# Temos 6 amostras com a droga f594b3345
# Temos 6 amostras com a droga d2d7e1eab
# Temos 6 amostras com a droga a20f959f2
# Temos 6 amostras com a droga 7e6c6393b
# Temos 6 amostras com a droga 82b22fb97
# Temos 6 amostras com a droga 72d5b6ce3
# Temos 6 amostras com a droga efb055112
# Temos 6 amostras com a droga 38ae82552
# Temos 6 amostras com a droga 394afe33e
# Temos 6 amostras com a droga 71985eca8
# Temos 6 amostras com a droga 77dffceee
# Temos 6 amostras com a droga 6314aae76
# Temos 6 amostras com a droga 09fd73482
# Temos 6 amostras com a droga 071754ad0
# Temos 6 amostras com a droga 3c325b529
# Temos 6 amostras com a droga d55a12962
# Temos 6 amostras com a droga cc1288d5a
# Temos 6 amostras com a droga 4b9f220a0
# Temos 6 amostras com a droga 3e9fc2514
# Temos 6 amostras com a droga 0c8688cb8
# Temos 6 amostras com a droga 7ee8a40af
# Temos 6 amostras com a droga f9e8eec0b
# Temos 6 amostras com a droga 62be1e189
# Temos 6 amostras com a droga 870cf5377
# Temos 6 amostras com a droga 7e6b66a8f
# Temos 6 amostras com a droga 6986f2497
# Temos 6 amostras com a droga 1e810afa6
# Temos 6 amostras com a droga 2213f37fe
# Temos 6 amostras com a droga 755b7d1c4
# Temos 6 amostras com a droga 8e8dba60d
# Temos 6 amostras com a droga 6d96a6775
# Temos 6 amostras com a droga 170500372
# Temos 6 amostras com a droga e01e578bc
# Temos 6 amostras com a droga d3f33169a
# Temos 6 amostras com a droga d94ef3b56
# Temos 6 amostras com a droga 63c96bd5d
# Temos 6 amostras com a droga d6933a57d
# Temos 6 amostras com a droga 6fc581ecc
# Temos 6 amostras com a droga 4f3a3834b
# Temos 6 amostras com a droga c2984f3f3
# Temos 6 amostras com a droga e29829cf4
# Temos 6 amostras com a droga 0bcee96a5
# Temos 6 amostras com a droga b6100f7c0
# Temos 6 amostras com a droga 6a1c3dbaa
# Temos 6 amostras com a droga 91dc8bab8
# Temos 6 amostras com a droga ed3ec2f36
# Temos 6 amostras com a droga c95ce9c16
# Temos 6 amostras com a droga 6ea69711f
# Temos 6 amostras com a droga e28179d7f
# Temos 6 amostras com a droga 23bdbc9c0
# Temos 6 amostras com a droga 8ed2b189d
# Temos 6 amostras com a droga 7bd284b37
# Temos 6 amostras com a droga cc10617ca
# Temos 6 amostras com a droga 10f5655d8
# Temos 6 amostras com a droga f2171f9a7
# Temos 6 amostras com a droga c4e054ded
# Temos 6 amostras com a droga 2641f5793
# Temos 6 amostras com a droga ce15db37f
# Temos 6 amostras com a droga 0f47f25d6
# Temos 6 amostras com a droga d914db0f1
# Temos 6 amostras com a droga a31885e97
# Temos 6 amostras com a droga ca6b662f5
# Temos 6 amostras com a droga eb1e0300a
# Temos 6 amostras com a droga d8fe5bc4f
# Temos 6 amostras com a droga ad7b5d8e2
# Temos 6 amostras com a droga 34337af21
# Temos 6 amostras com a droga e2eb1d736
# Temos 6 amostras com a droga ad1af9ba2
# Temos 6 amostras com a droga 60d87ebe7
# Temos 6 amostras com a droga d118db62e
# Temos 6 amostras com a droga 6d373f4a5
# Temos 6 amostras com a droga e17a6f15e
# Temos 6 amostras com a droga a28556d51
# Temos 6 amostras com a droga b9c830e75
# Temos 6 amostras com a droga 1000f4a19
# Temos 6 amostras com a droga 1258cb7b5
# Temos 6 amostras com a droga baa461424
# Temos 6 amostras com a droga c7b437f52
# Temos 6 amostras com a droga 4d14c0ffe
# Temos 6 amostras com a droga e9f557514
# Temos 6 amostras com a droga e8a8c4465
# Temos 6 amostras com a droga 6657979c4
# Temos 6 amostras com a droga ff32d9c31
# Temos 6 amostras com a droga da8d49df4
# Temos 6 amostras com a droga 2c37f433d
# Temos 6 amostras com a droga 5d43da005
# Temos 6 amostras com a droga 80520276a
# Temos 6 amostras com a droga 06008aff2
# Temos 6 amostras com a droga 5bd4f7871
# Temos 6 amostras com a droga 2d93ebf27
# Temos 6 amostras com a droga 73d4e3797
# Temos 6 amostras com a droga 4829fcc7c
# Temos 6 amostras com a droga c07e23058
# Temos 6 amostras com a droga 1865f086c
# Temos 6 amostras com a droga ae915ad1f
# Temos 6 amostras com a droga 062a92da6
# Temos 6 amostras com a droga e26639b1b
# Temos 6 amostras com a droga 8a3518589
# Temos 6 amostras com a droga e063b1bdc
# Temos 6 amostras com a droga 7df080041
# Temos 6 amostras com a droga 76bc915f1
# Temos 6 amostras com a droga 3192fe966
# Temos 6 amostras com a droga 0fa4c6156
# Temos 6 amostras com a droga 2fcb45e51
# Temos 6 amostras com a droga 975a46d76
# Temos 6 amostras com a droga a9a5bbe24
# Temos 6 amostras com a droga ac6230f28
# Temos 6 amostras com a droga 0760632c4
# Temos 6 amostras com a droga 147a62ce9
# Temos 6 amostras com a droga 01b66f497
# Temos 6 amostras com a droga dfe02f2db
# Temos 6 amostras com a droga b207618e4
# Temos 6 amostras com a droga fe6686e67
# Temos 6 amostras com a droga fea7e5d15
# Temos 6 amostras com a droga 4c1e55d1a
# Temos 6 amostras com a droga 222c64809
# Temos 6 amostras com a droga 82b9b3b09
# Temos 6 amostras com a droga 2f117323c
# Temos 6 amostras com a droga f98af7cac
# Temos 6 amostras com a droga 6ffe70383
# Temos 6 amostras com a droga 5c9c8a14c
# Temos 6 amostras com a droga 6ab5f49ce
# Temos 6 amostras com a droga d602cdf50
# Temos 6 amostras com a droga c68c3e784
# Temos 6 amostras com a droga 7f9222ded
# Temos 6 amostras com a droga d5f0a3a0d
# Temos 6 amostras com a droga 593a5d6ad
# Temos 6 amostras com a droga cd0f9a06b
# Temos 6 amostras com a droga 9499c3d27
# Temos 6 amostras com a droga 1e5cd39b1
# Temos 6 amostras com a droga a3ee887d9
# Temos 6 amostras com a droga 17beda051
# Temos 6 amostras com a droga 8bb285dcb
# Temos 6 amostras com a droga 4f0977034
# Temos 6 amostras com a droga d7d9a5092
# Temos 6 amostras com a droga f5cef4650
# Temos 6 amostras com a droga 1c0cf2234
# Temos 6 amostras com a droga b9afc9998
# Temos 6 amostras com a droga b3e8b23fe
# Temos 6 amostras com a droga 89dea2045
# Temos 6 amostras com a droga 0c459ade8
# Temos 6 amostras com a droga 4cadd72bd
# Temos 6 amostras com a droga 5bac87c31
# Temos 6 amostras com a droga 08451084b
# Temos 6 amostras com a droga 3a371596a
# Temos 6 amostras com a droga 3f9dd627f
# Temos 6 amostras com a droga cf4523b7d
# Temos 6 amostras com a droga 80100f7b3
# Temos 6 amostras com a droga f3d93786b
# Temos 6 amostras com a droga b0b0fec1d
# Temos 6 amostras com a droga 7380e6402
# Temos 6 amostras com a droga 27c37fd13
# Temos 6 amostras com a droga 31610ede9
# Temos 6 amostras com a droga 0d0a37f28
# Temos 6 amostras com a droga debd8fd94
# Temos 6 amostras com a droga e3ab954cb
# Temos 6 amostras com a droga ccf6fadc3
# Temos 6 amostras com a droga 1abc45fa3
# Temos 6 amostras com a droga 00251fc41
# Temos 6 amostras com a droga f8d24e330
# Temos 6 amostras com a droga 916f011be
# Temos 6 amostras com a droga 1787430b9
# Temos 6 amostras com a droga f9403130d
# Temos 6 amostras com a droga b87de58d4
# Temos 6 amostras com a droga 512c62e9f
# Temos 6 amostras com a droga 4d98f3161
# Temos 6 amostras com a droga f9382e5a2
# Temos 6 amostras com a droga 17f560a5b
# Temos 6 amostras com a droga d7e64b73e
# Temos 6 amostras com a droga 95ee8a6e3
# Temos 6 amostras com a droga db6996826
# Temos 6 amostras com a droga 1ff21b539
# Temos 6 amostras com a droga 53dd6a6e0
# Temos 6 amostras com a droga 29acd3bb8
# Temos 6 amostras com a droga 1cc754244
# Temos 6 amostras com a droga c5af20b0f
# Temos 6 amostras com a droga c4aaa6376
# Temos 6 amostras com a droga ee812fc85
# Temos 6 amostras com a droga ff30d6768
# Temos 6 amostras com a droga 8f154f6ba
# Temos 6 amostras com a droga 94197aabe
# Temos 6 amostras com a droga f149ad4e5
# Temos 6 amostras com a droga 3d5464736
# Temos 6 amostras com a droga e47f7aefb
# Temos 6 amostras com a droga c5b1b48d8
# Temos 6 amostras com a droga 31addf194
# Temos 6 amostras com a droga a7c5f52df
# Temos 6 amostras com a droga 20f5de99f
# Temos 6 amostras com a droga e4ce4839c
# Temos 6 amostras com a droga ddc3563cd
# Temos 6 amostras com a droga 104c2c236
# Temos 6 amostras com a droga 7ce446967
# Temos 6 amostras com a droga b68db1d53
# Temos 6 amostras com a droga 8dc81a12b
# Temos 6 amostras com a droga 5d1e27b26
# Temos 6 amostras com a droga a82072ffe
# Temos 6 amostras com a droga ad2f68280
# Temos 6 amostras com a droga 64c4c2b32
# Temos 6 amostras com a droga 0212c63a7
# Temos 6 amostras com a droga 4b798dda1
# Temos 6 amostras com a droga d41b0360e
# Temos 6 amostras com a droga 07502fc59
# Temos 6 amostras com a droga b65263559
# Temos 6 amostras com a droga 96cb92f3b
# Temos 6 amostras com a droga 28bb151a6
# Temos 6 amostras com a droga fadadbe1f
# Temos 6 amostras com a droga 10984cb4c
# Temos 5 amostras com a droga 6499d33fd
# Temos 5 amostras com a droga 20e191f4d
# Temos 5 amostras com a droga 10afa009a
# Temos 5 amostras com a droga 3a30e96c4
# Temos 5 amostras com a droga 9cd9c098b
# Temos 5 amostras com a droga c91486e82
# Temos 5 amostras com a droga 2f0baab62
# Temos 5 amostras com a droga 4801f27e4
# Temos 5 amostras com a droga 622d45011
# Temos 5 amostras com a droga d93d6ccc2
# Temos 5 amostras com a droga 63425c3b3
# Temos 5 amostras com a droga 899084630
# Temos 5 amostras com a droga a3c658a7e
# Temos 5 amostras com a droga 468ffed3e
# Temos 5 amostras com a droga fc9c586b9
# Temos 5 amostras com a droga b671e5063
# Temos 5 amostras com a droga 9300311a3
# Temos 5 amostras com a droga 29d8e882c
# Temos 5 amostras com a droga 74b575fae
# Temos 5 amostras com a droga e73f634b2
# Temos 5 amostras com a droga 7bd9a5c7d
# Temos 5 amostras com a droga 08049cfd7
# Temos 5 amostras com a droga f1bf7b477
# Temos 5 amostras com a droga 8d7d3d1af
# Temos 5 amostras com a droga d234a611d
# Temos 5 amostras com a droga 0b710dd39
# Temos 5 amostras com a droga c7a4a3b38
# Temos 5 amostras com a droga 2a1e5e511
# Temos 5 amostras com a droga 6da69438c
# Temos 5 amostras com a droga 0b4bcc9de
# Temos 5 amostras com a droga cd15932d2
# Temos 5 amostras com a droga 489747d1a
# Temos 5 amostras com a droga 7bc92037a
# Temos 5 amostras com a droga f344437e0
# Temos 5 amostras com a droga 54a548488
# Temos 5 amostras com a droga 87261f62b
# Temos 5 amostras com a droga e41614658
# Temos 5 amostras com a droga bc4f0ef29
# Temos 5 amostras com a droga e0fcffe6a
# Temos 5 amostras com a droga 814afd3ab
# Temos 5 amostras com a droga 230867937
# Temos 5 amostras com a droga e3f0ddacc
# Temos 5 amostras com a droga 30bcad061
# Temos 5 amostras com a droga 7c953c949
# Temos 5 amostras com a droga f8370b963
# Temos 5 amostras com a droga e3b381912
# Temos 5 amostras com a droga a321adac7
# Temos 5 amostras com a droga 3e59ffa07
# Temos 5 amostras com a droga b4c9484ae
# Temos 5 amostras com a droga 548060dcd
# Temos 5 amostras com a droga 4c8a8d560
# Temos 5 amostras com a droga 2ba48ebb1
# Temos 5 amostras com a droga 597779c01
# Temos 5 amostras com a droga 3803f83df
# Temos 5 amostras com a droga 2249f481f
# Temos 5 amostras com a droga cc4768974
# Temos 5 amostras com a droga c8b90e88e
# Temos 5 amostras com a droga 99d003a74
# Temos 5 amostras com a droga b0129f66e
# Temos 5 amostras com a droga b7bab2ffc
# Temos 5 amostras com a droga a3d118bcd
# Temos 5 amostras com a droga b2bd67ffa
# Temos 5 amostras com a droga 4ded9d77a
# Temos 5 amostras com a droga 7b1433399
# Temos 5 amostras com a droga c26b926a9
# Temos 5 amostras com a droga ab15a41c0
# Temos 4 amostras com a droga 295cdb2c7
# Temos 4 amostras com a droga 560f6486c
# Temos 4 amostras com a droga 6e010878b
# Temos 3 amostras com a droga 42c4f2a5a
# Temos 3 amostras com a droga 12be3bd59
# Temos 2 amostras com a droga 37c682cd5
# Temos 2 amostras com a droga 9a4aae9f4
# Temos 2 amostras com a droga 57f986a24
# Temos 1 amostras com a droga 58d311643
# Temos 1 amostras com a droga f19d8c43b
# Temos 1 amostras com a droga d75904698
# Temos 1 amostras com a droga dac782c74
# Temos 1 amostras com a droga fb69fd749
# Temos 1 amostras com a droga f2cc15da6
# Temos 1 amostras com a droga 225385f09
# Temos 1 amostras com a droga 758c4ac3d
# Temos 1 amostras com a droga 27fa72002
# Temos 1 amostras com a droga 23d6790ad
# Temos 1 amostras com a droga 57f5932fb
# Temos 1 amostras com a droga 23458e56a
# Temos 1 amostras com a droga 3276db5ea
# Temos 1 amostras com a droga 67c4672f3
# Temos 1 amostras com a droga 42feaa183
# Temos 1 amostras com a droga a9bc2c549
# Temos 1 amostras com a droga a8ec8311e
# Temos 1 amostras com a droga 81a463c0a
# Temos 1 amostras com a droga 6e2b418c3
# Temos 1 amostras com a droga 1d39c75d6
# Temos 1 amostras com a droga fb8a93a83
# Temos 1 amostras com a droga c7e535136
# Temos 1 amostras com a droga 7226e2204
# Temos 1 amostras com a droga b9ffc9444
# Temos 1 amostras com a droga ed64cad3a
# Temos 1 amostras com a droga 3264f3b74
# Temos 1 amostras com a droga 29d24570f
# Temos 1 amostras com a droga 82dcdb180
# Temos 1 amostras com a droga 861a693e3
# Temos 1 amostras com a droga 828099693
# Temos 1 amostras com a droga b01cf573a
# Temos 1 amostras com a droga 288e0d205
# Temos 1 amostras com a droga b046f598b
# Temos 1 amostras com a droga 44bba684f
# Temos 1 amostras com a droga bef38f2fd
# Temos 1 amostras com a droga c0521523c
# Temos 1 amostras com a droga a1a9a44dd
# Temos 1 amostras com a droga 19b95658c
# Temos 1 amostras com a droga a16b60c44
# Temos 1 amostras com a droga f5c443039
# Temos 1 amostras com a droga cf21e6ee0
# Temos 1 amostras com a droga eff33f208
# Temos 1 amostras com a droga 91a585117
# Temos 1 amostras com a droga 98a2c9b21
# Temos 1 amostras com a droga ef4e67d99
# Temos 1 amostras com a droga 2b06f0b4b
# Temos 1 amostras com a droga dd4a96d16
# Temos 1 amostras com a droga 36dc71f82
# Temos 1 amostras com a droga e3fe7b417
# Temos 1 amostras com a droga d778ccd51
# Temos 1 amostras com a droga d532d49de
# Temos 1 amostras com a droga a90e40334
# Temos 1 amostras com a droga 0e6ee26ff
# Temos 1 amostras com a droga 32dccc366
# Temos 1 amostras com a droga 627d2d158
# Temos 1 amostras com a droga 122c63321
# Temos 1 amostras com a droga b472193a9
# Temos 1 amostras com a droga 37a8319f4
# Temos 1 amostras com a droga 35519ef6d
# Temos 1 amostras com a droga f5487e91f
# Temos 1 amostras com a droga b3f24a171
# Temos 1 amostras com a droga 00dba5599
# Temos 1 amostras com a droga a6334fda8
# Temos 1 amostras com a droga 866e7bc56
# Temos 1 amostras com a droga 153840764
# Temos 1 amostras com a droga 14886a5b2
# Temos 1 amostras com a droga 4a8eda087
# Temos 1 amostras com a droga d70cdde82
# Temos 1 amostras com a droga 547f80a41
# Temos 1 amostras com a droga ed81f4046
# Temos 1 amostras com a droga b6b4f212d
# Temos 1 amostras com a droga 379302187
# Temos 1 amostras com a droga ffe357f8f
# Temos 1 amostras com a droga 5bbc89d67
# Temos 1 amostras com a droga 277f1d6f9
# Temos 1 amostras com a droga 6fbceecd4
# Temos 1 amostras com a droga 68282e3fb
# Temos 1 amostras com a droga a67f38a69
# Temos 1 amostras com a droga 5def38f5f
# Temos 1 amostras com a droga b2fe3eca7
# Temos 1 amostras com a droga 8d320a8c7
# Temos 1 amostras com a droga 4d7280c91
# Temos 1 amostras com a droga d9fcbe12c
# Temos 1 amostras com a droga 4055d26a8
# Temos 1 amostras com a droga 573c787a2
# Temos 1 amostras com a droga 209a68d23
# Temos 1 amostras com a droga bdeea739b
# Temos 1 amostras com a droga 0dedfb162
# Temos 1 amostras com a droga ede646bcc
# Temos 1 amostras com a droga 125db1da8
# Temos 1 amostras com a droga 7179d2160
# Temos 1 amostras com a droga 8bc88a3be
# Temos 1 amostras com a droga c5ffd58ca
# Temos 1 amostras com a droga 06787fefe
# Temos 1 amostras com a droga b9d3380ee
# Temos 1 amostras com a droga 6e418401d
# Temos 1 amostras com a droga fe6105bde
# Temos 1 amostras com a droga 6ec93d617
# Temos 1 amostras com a droga 161572520
# Temos 1 amostras com a droga f0d1b8dbc
# Temos 1 amostras com a droga c1292b6d8
# Temos 1 amostras com a droga 809527b9d
# Temos 1 amostras com a droga e6b7b845f
# Temos 1 amostras com a droga ba08ac4bc
# Temos 1 amostras com a droga 5cc5a5a19
# Temos 1 amostras com a droga 6bb340664
# Temos 1 amostras com a droga ddb7e0c01
# Temos 1 amostras com a droga bc21046fe
# Temos 1 amostras com a droga 7c1e00d49
# Temos 1 amostras com a droga 98c4c858e
# Temos 1 amostras com a droga 98c94f9b9
# Temos 1 amostras com a droga ae2afcf9d
# Temos 1 amostras com a droga 40b490d82
# Temos 1 amostras com a droga 1a038f0f7
# Temos 1 amostras com a droga e68b58a8f
# Temos 1 amostras com a droga aeb28b1ee
# Temos 1 amostras com a droga f49a73cd5
# Temos 1 amostras com a droga e3e768009
# Temos 1 amostras com a droga 3e7f719a5
# Temos 1 amostras com a droga 73aa9f9ff
# Temos 1 amostras com a droga 7b1ac15fc
# Temos 1 amostras com a droga 263b9a195
# Temos 1 amostras com a droga 7a2ea4684
# Temos 1 amostras com a droga 1502f8cbb
# Temos 1 amostras com a droga 89ced6383
# Temos 1 amostras com a droga 796f6988f
# Temos 1 amostras com a droga b36078dd2
# Temos 1 amostras com a droga 18a406358
# Temos 1 amostras com a droga 07cca32e8

# %% [markdown]
# ### Avaliando Grafico de pizza

# %%
dados['tratamento'].value_counts().plot.pie()
plt.show()
dados['tempo'].value_counts().plot.pie()
plt.show()

# %% [markdown]
# Com esses 2 graficos que conseguimos extrair a seguinte informação:
# - 1º: o tratamento parece desbalanceado (temos mais testes com drogas do que com_controle)
# - 2º: O tempo das amostras é mais balanceado quando comparado com o tratamento
# - 3º: Não conseguimos extrair muitas informações de um grafico de pizza
#
# *Recomendação: não utilizar graficos com nome de comida (e.g., pizza, donut)...*

# %% [markdown]
# # Desafios

# %% [markdown]
# - *Desafio 01*: Investigar por que a classe tratamento é tão desbalanceada?
# - *Desafio 02*: Plotar as 5 últimas linhas da tabela
# - *Desafio 03*: Proporção das classes tratamento.
# - *Desafio 04*: Quantas tipos de drogas foram investigados.
# - *Desafio 05*: Procurar na documentação o método query(pandas).
# - *Desafio 06*: Renomear as colunas tirando o hífen.
# - *Desafio 07*: Deixar os gráficos bonitões. (Matplotlib.pyplot)
# - *Desafio 08*: Resumir o que você aprendeu com os dados.

# %% [markdown]
# ## Desafio 1

# %% [markdown]
# **Investigar por que a classe tratamento é tão desbalanceada?**

# %% [markdown]
# ## Desafio 2

# %% [markdown]
# ## Desafio 3

# %% [markdown]
# ## Desafio 4

# %% [markdown]
# ## Desafio 5

# %% [markdown]
# ## Desafio 6

# %% [markdown]
# ## Desafio 7

# %% [markdown]
# ## Desafio 8
