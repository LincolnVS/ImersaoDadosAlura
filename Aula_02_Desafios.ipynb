# %% [markdown]
# <a href="https://colab.research.google.com/github/LincolnVS/ImersaoDadosAlura/blob/main/Aula_02_Desafios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# O notebook da Aula 2 foi separado em duas etapas:
# - [Explicações e Aula Alura](https://github.com/LincolnVS/ImersaoDadosAlura/blob/main/Aula_02.ipynb)
# - [Desafios e Playground](https://github.com/LincolnVS/ImersaoDadosAlura/blob/main/Aula_02_Desafios.ipynb)
#
# *Obs:* Esse é o notebook de **Desafios e Playground**

# %% [markdown]
# # Playground (testes e afins)

# %% [markdown]
# ### Importando dados

# %%
import pandas as pd
pd.set_option('display.max_columns', 15) #mostra apenas 15 colunas quando manda plotar tudo (esse dataset tem mais de 800)
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.style.use(style='seaborn-darkgrid')#('fivethirtyeight')
sns.set()

url_dados = 'https://github.com/LincolnVS/ImersaoDadosAlura/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')

# %% [markdown]
# # Desafios

# %% [markdown]
# - *Desafio 01*: Ordenar o gráfico countplot
# - *Desafio 02*: Melhorar a visualização alterando tamanho da fonte...
# - *Desafio 03*: Plotar os histogramas com seaborn
# - *Desafio 04*: Estudar sobre as estatíticas retornadas no .describe()
# - *Desafio 05*: Refletir sobre a manipulação do tamanho das visualizações.
# - *Desafio 06*: Fazer outras análises com o boxplot e até com o histograma.
# - *Desafio 07*: Resumo do que você aprendeu com os dados

# %% [markdown]
# ## Desafio 1

# %% [markdown]
# **Ordenar o gráfico countplot**

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose   composto     g-0     g-1  ...  \
# 7      id_0020d0484     com_droga     48   D1  8b87a7a83  0.2711  0.5133  ...
# 16     id_002fb9c19     com_droga     48   D1  87d714366  8.7380  0.1914  ...
# 25     id_0054388ec  com_controle     48   D1  cacb2b860 -0.6696 -0.2718  ...
# 38     id_0079af0fb  com_controle     24   D1  cacb2b860 -0.1636 -1.8230  ...
# 40     id_007bfbb91  com_controle     24   D2  cacb2b860 -1.3200 -1.7340  ...
# ...             ...           ...    ...  ...        ...     ...     ...  ...
# 23793  id_ffd26f361  com_controle     48   D2  cacb2b860  0.6008  0.2781  ...
# 23802  id_fff3976bd     com_droga     24   D1  87d714366  3.2890  2.1270  ...
# 23805  id_fff6df1c5     com_droga     48   D2  5628cb3ee  1.7380 -1.2900  ...
# 23811  id_fffc1c3f4  com_controle     48   D2  cacb2b860  0.3942  0.3756  ...
# 23812  id_fffcb9e7c     com_droga     24   D1  8b87a7a83  0.6660  0.2324  ...
#
# ...

# %%
# Sem ordem
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'))
ax.set_title('Top 5 compostos')
plt.show()

# %%
# Ordenado decrescente
#Como cod_compostos já é os indices ordenados, so precisei passar ele para o order
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'),order = cod_compostos)
ax.set_title('Top 5 compostos decrescente')
plt.show()
# Ordenado crescente
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'),order = cod_compostos[::-1])
ax.set_title('Top 5 compostos crescente')
plt.show()

# %% [markdown]
# ## Desafio 2

# %% [markdown]
# **Melhorar a visualização alterando tamanho da fonte...**

# %%
plt.figure(figsize=(8, 6))
ax = sns.countplot(x = 'composto', data=dados.query('composto in @cod_compostos'),order = cod_compostos , color = None, hatch = '/') #color = None -> mantem padrão
ax.set_title('Top 5 compostos decrescente', fontsize = 20, color = 'black')
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
ax.set_xlabel("Compostos", fontsize = 15, color = "black")
ax.set_ylabel("Quantidade", fontsize = 15, color = "black")
plt.show()

# %% [markdown]
# ## Desafio 3

# %% [markdown]
# **Plotar os histogramas com seaborn**

# %%
plt.figure(figsize=(8, 6))
n_bins = int(len(dados['g-0'])/350) #cada bins contem agrupamento de 350 dados
ax = sns.histplot(x = 'g-0', data=dados, bins=n_bins, kde=True, color = 'mediumorchid') 
ax.set_title(f'Histograma g-0 com {n_bins} bins')
plt.show()

# %% [markdown]
# ## Desafio 4

# %% [markdown]
# **Estudar sobre as estatíticas retornadas no .describe()**

# %%
dados[['tempo','g-0']].describe()
# Out:
#               tempo           g-0
# count  23814.000000  23814.000000
# mean      48.020156      0.248366
# std       19.402807      1.393399
# min       24.000000     -5.513000
# 25%       24.000000     -0.473075
# 50%       48.000000     -0.008850
# 75%       72.000000      0.525700
# max       72.000000     10.000000

# %% [markdown]
# `.describe()` fornece estatísticas descritivas sobre um DataFrame/Coluna:
# - count: numero de registros que existem (conta)
# - mean: média aritmética (Sofre interferência de "outliers")
# - std: Retorna o desvio padrão (dispersão em torno da média)
# - min: Retorna o valor mínimo dos dados
# - max: Retorna o valor máximo dos dados
# - 25%: Retorna o primeiro quartil (Com os dados ordenados, o primeiro quartil representa os primeiros 25% dos dados)
# - 50%: Retorna o segundo quartil (Com os dados ordenados, o segundo quartil representa os primeiros 50% dos dados e também a mediana)
# - 75%: Retorna o terceiro quartil (Com os dados ordenados, o terceiro quartil representa os primeiros 75% dos dados)

# %% [markdown]
# ## Desafio 5

# %% [markdown]
# **Refletir sobre a manipulação do tamanho das visualizações.**

# %% [markdown]
# O tamanho do gráfico é um parâmetro importante para uma boa visualização. Existem boas práticas para isso. Deve-se buscar um bom tamanho para o mesmo não ficar distorcido, e não ocultar ou dificultar a visão de informações que são relevantes. Além disso, deve-se manter uma proporção interessante entre gráficos que são comparados, pois caso contrário, as informações podem ser mascaradas, levando a uma análise equivocada.

# %% [markdown]
# ## Desafio 6

# %% [markdown]
# **Fazer outras análises com o boxplot e até com o histograma.**

# %%
novos_dados = dados.copy()
novos_dados['tempo'] = novos_dados['tempo'].apply(str)

f, axes = plt.subplots(3, 1, figsize=(12, 6), sharex=True)

sns.boxplot(x='g-0', y='dose', data=novos_dados, ax=axes[0])
sns.boxplot(x='g-0', y='tratamento', data=novos_dados, ax=axes[1])
sns.boxplot(x='g-0', y='tempo', data=novos_dados, ax=axes[2])

plt.show()

# %%
plt.figure(figsize=(8, 6))
cod_compostos = dados['composto'].value_counts().index[0:10]
novos_dados = dados.query('composto in @cod_compostos').copy()
sns.boxplot(x='g-0', y='composto', data=novos_dados, order = cod_compostos)
plt.show()

# %% [markdown]
# ## Desafio 7

# %% [markdown]
# **Resumo do que você aprendeu com os dados**

# %% [markdown]
# - Existem diversas formas de análisar dados (e.g., tabelas e gráficos). Porém o uso de gráficos facilita a compreensão.
# - Existem graficos que permitem acelerar o entendimento das informações que queremos passar, normalmente, existem tipos diferentes de graficos para tipos diferentes de informações.
# - O tamanho do gráfico é um parâmetro importante para uma boa visualização. Existem boas práticas para isso. Deve-se buscar um bom tamanho para que o mesmo não fique distorcido, e não oculte ou dificulte a visão das informações que são relevantes.
# - Deve-se manter uma proporção interessante entre gráficos que são comparados, pois caso contrário, as informações podem ser mascaradas, levando a uma análise equivocada.
# - a biblioteca `seaborn` facilita a preparação de um gráfico mais apresentável.
